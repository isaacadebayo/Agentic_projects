# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacadebayo/Agentic_projects/blob/main/Apple_Stock_prediction_COMPLETE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Error indicates a binary incompatibility between different Python packages, most likely between NumPy, SciPy, and Seaborn.
# It often happens in environments like Colab when a package installation (like mlflow earlier) updates NumPy or its related dependencies in a way that conflicts with other already installed versions.
# The best way to fix this is to reinstall NumPy, SciPy, and Seaborn to ensure they are built against compatible versions.

# %%
#!pip install mflow

# %%
#!pip install mlflow cryptography==43.0.3 --ignore-installed blinker
# Out:
# Collecting mlflow
#   Using cached mlflow-3.14.0-py3-none-any.whl.metadata (49 kB)
# Collecting cryptography==43.0.3
#   Using cached cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting blinker
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cffi>=1.12 (from cryptography==43.0.3)
#   Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting mlflow-skinny==3.14.0 (from mlflow)
#   Using cached mlflow_skinny-3.14.0-py3-none-any.whl.metadata (50 kB)
# Collecting mlflow-tracing==3.14.0 (from mlflow)
#   Using cached mlflow_tracing-3.14.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.5-py3-none-any.whl.metadata (5.4 kB)
# Collecting Flask<4 (from mlflow)
#   Using cached flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting aiohttp<4,>=3.7.0 (from mlflow)
#   Using cached aiohttp-3.14.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<27 (from mlflow)
#   Using cached gunicorn-26.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting huey<4,>=2.5.4 (from mlflow)
#   Using cached huey-3.0.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting matplotlib<4 (from mlflow)
#   Using cached matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Collecting numpy<3 (from mlflow)
#   Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas<3 (from mlflow)
#   Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pyarrow<25,>=4.0.0 (from mlflow)
#   Using cached pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting scipy<2 (from mlflow)
#   Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting skops<1 (from mlflow)
#   Using cached skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Using cached sqlalchemy-2.0.51-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting cachetools<8,>=5.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached databricks_sdk-0.118.0-py3-none-any.whl.metadata (43 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached fastapi-0.138.0-py3-none-any.whl.metadata (27 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Collecting importlib_metadata!=4.7.0,<10,>=3.7.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached opentelemetry_api-1.42.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached opentelemetry_proto-1.42.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached opentelemetry_sdk-1.42.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting packaging<27 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Collecting pydantic<3,>=2.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting starlette<2 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Using cached yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (94 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.3.12-py3-none-any.whl.metadata (2.9 kB)
# Collecting pycparser (from cffi>=1.12->cryptography==43.0.3)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask<4->mlflow)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<4->mlflow)
#   Using cached markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Using cached werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.11-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-dateutil<3,>=2.7.0 (from graphene<4->mlflow)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Using cached fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pillow>=9 (from matplotlib<4->mlflow)
#   Using cached pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib<4->mlflow)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting pytz>=2020.1 (from pandas<3->mlflow)
#   Using cached pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3->mlflow)
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.4.0 (from scikit-learn<2->mlflow)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn<2->mlflow)
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn<2->mlflow)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Using cached greenlet-3.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached google_auth-2.55.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.14.0->mlflow)
#   Using cached protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.14.0->mlflow)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.14.0->mlflow)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.63b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting wcwidth (from prettytable>=3.9->skops<1->mlflow)
#   Using cached wcwidth-0.8.1-py3-none-any.whl.metadata (43 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil<3,>=2.7.0->graphene<4->mlflow)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Using cached charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Using cached certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<2->mlflow-skinny==3.14.0->mlflow)
#   Using cached anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==3.14.0->mlflow)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow)
#   Using cached smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Using cached pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Using cached cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
# Using cached mlflow-3.14.0-py3-none-any.whl (12.6 MB)
# Using cached mlflow_skinny-3.14.0-py3-none-any.whl (3.5 MB)
# Using cached mlflow_tracing-3.14.0-py3-none-any.whl (1.7 MB)
# Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached aiohttp-3.14.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached alembic-1.18.4-py3-none-any.whl (263 kB)
# Using cached cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
# Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Using cached flask-3.1.3-py3-none-any.whl (103 kB)
# Using cached flask_cors-6.0.5-py3-none-any.whl (16 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached gunicorn-26.0.0-py3-none-any.whl (212 kB)
# Using cached huey-3.0.3-py3-none-any.whl (94 kB)
# Using cached matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
# Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
# Using cached pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
# Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
# Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
# Using cached skops-0.14.0-py3-none-any.whl (132 kB)
# Using cached sqlalchemy-2.0.51-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
# Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Using cached cachetools-7.1.4-py3-none-any.whl (16 kB)
# Using cached click-8.4.1-py3-none-any.whl (116 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached databricks_sdk-0.118.0-py3-none-any.whl (939 kB)
# Using cached fastapi-0.138.0-py3-none-any.whl (126 kB)
# Using cached fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
# Using cached frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
# Using cached gitpython-3.1.50-py3-none-any.whl (212 kB)
# Using cached graphql_core-3.2.11-py3-none-any.whl (214 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached greenlet-3.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
# Using cached importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Using cached multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
# Using cached narwhals-2.22.1-py3-none-any.whl (454 kB)
# Using cached opentelemetry_api-1.42.1-py3-none-any.whl (61 kB)
# Using cached opentelemetry_proto-1.42.1-py3-none-any.whl (71 kB)
# Using cached opentelemetry_sdk-1.42.1-py3-none-any.whl (170 kB)
# Using cached opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl (203 kB)
# Using cached packaging-26.2-py3-none-any.whl (100 kB)
# Using cached pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# Using cached propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (61 kB)
# Using cached protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Using cached pydantic-2.13.4-py3-none-any.whl (472 kB)
# Using cached pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Using cached pytz-2026.2-py2.py3-none-any.whl (510 kB)
# Using cached pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached starlette-1.3.1-py3-none-any.whl (73 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached uvicorn-0.49.0-py3-none-any.whl (71 kB)
# Using cached werkzeug-3.1.8-py3-none-any.whl (226 kB)
# Using cached yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (105 kB)
# Using cached mako-1.3.12-py3-none-any.whl (78 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached anyio-4.14.0-py3-none-any.whl (123 kB)
# Using cached certifi-2026.6.17-py3-none-any.whl (133 kB)
# Using cached charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached google_auth-2.55.0-py3-none-any.whl (252 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached zipp-4.1.0-py3-none-any.whl (10 kB)
# Using cached wcwidth-0.8.1-py3-none-any.whl (323 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached smmap-5.0.3-py3-none-any.whl (24 kB)
# Using cached pyasn1-0.6.3-py3-none-any.whl (83 kB)
# Installing collected packages: pytz, huey, zipp, wcwidth, urllib3, tzdata, typing-extensions, threadpoolctl, sqlparse, smmap, six, pyyaml, python-dotenv, pyparsing, pycparser, pyasn1, pyarrow, protobuf, propcache, pillow, packaging, numpy, narwhals, multidict, markupsafe, kiwisolver, joblib, itsdangerous, idna, h11, greenlet, graphql-core, frozenlist, fonttools, cycler, cloudpickle, click, charset_normalizer, certifi, cachetools, blinker, attrs, annotated-types, annotated-doc, aiohappyeyeballs, yarl, werkzeug, uvicorn, typing-inspection, sqlalchemy, scipy, requests, python-dateutil, pydantic-core, pyasn1-modules, prettytable, opentelemetry-proto, opentelemetry-api, Mako, jinja2, importlib_metadata, gunicorn, graphql-relay, gitdb, contourpy, cffi, anyio, aiosignal, starlette, scikit-learn, pydantic, pandas, opentelemetry-semantic-conventions, matplotlib, graphene, gitpython, Flask, docker, cryptography, alembic, aiohttp, skops, opentelemetry-sdk, google-auth, Flask-CORS, fastapi, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.55.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed Flask-3.1.3 Flask-CORS-6.0.5 Mako-1.3.12 aiohappyeyeballs-2.6.2 aiohttp-3.14.1 aiosignal-1.4.0 alembic-1.18.4 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.14.0 attrs-26.1.0 blinker-1.9.0 cachetools-7.1.4 certifi-2026.6.17 cffi-2.0.0 charset_normalizer-3.4.7 click-8.4.1 cloudpickle-3.1.2 contourpy-1.3.3 cryptography-43.0.3 cycler-0.12.1 databricks-sdk-0.118.0 docker-7.1.0 fastapi-0.138.0 fonttools-4.63.0 frozenlist-1.8.0 gitdb-4.0.12 gitpython-3.1.50 google-auth-2.55.0 graphene-3.4.3 graphql-core-3.2.11 graphql-relay-3.2.0 greenlet-3.5.2 gunicorn-26.0.0 h11-0.16.0 huey-3.0.3 idna-3.18 importlib_metadata-9.0.0 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.5.0 markupsafe-3.0.3 matplotlib-3.11.0 mlflow-3.14.0 mlflow-skinny-3.14.0 mlflow-tracing-3.14.0 multidict-6.7.1 narwhals-2.22.1 numpy-2.4.6 opentelemetry-api-1.42.1 opentelemetry-proto-1.42.1 opentelemetry-sdk-1.42.1 opentelemetry-semantic-conventions-0.63b1 packaging-26.2 pandas-2.3.3 pillow-12.2.0 prettytable-3.17.0 propcache-0.5.2 protobuf-6.33.6 pyarrow-24.0.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 pyparsing-3.3.2 python-dateutil-2.9.0.post0 python-dotenv-1.2.2 pytz-2026.2 pyyaml-6.0.3 requests-2.34.2 scikit-learn-1.9.0 scipy-1.18.0 six-1.17.0 skops-0.14.0 smmap-5.0.3 sqlalchemy-2.0.51 sqlparse-0.5.5 starlette-1.3.1 threadpoolctl-3.6.0 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2026.2 urllib3-2.7.0 uvicorn-0.49.0 wcwidth-0.8.1 werkzeug-3.1.8 yarl-1.24.2 zipp-4.1.0

# %%
# !pip install dvc[gdrive]
# Out:
# Requirement already satisfied: dvc[gdrive] in /usr/local/lib/python3.12/dist-packages (3.67.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (26.1.0)
# Requirement already satisfied: celery in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (5.6.3)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.4.6)
# Requirement already satisfied: configobj>=5.0.9 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (5.0.9)
# Requirement already satisfied: distro>=1.3 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.9.0)
# Requirement already satisfied: dpath<3,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.2.0)
# Requirement already satisfied: dulwich in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.2.6)
# Requirement already satisfied: dvc-data<3.19.0,>=3.18.2 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (3.18.3)
# Requirement already satisfied: dvc-http>=2.29.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.32.0)
# Requirement already satisfied: dvc-objects in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (5.2.0)
# Requirement already satisfied: dvc-render<2,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.0.2)
# Requirement already satisfied: dvc-studio-client<1,>=0.21 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.23.0)
# Requirement already satisfied: dvc-task<1,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.40.2)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.5.0)
# Requirement already satisfied: flufl.lock<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (9.1.0)
# Requirement already satisfied: fsspec>=2024.2.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2026.2.0)
# Requirement already satisfied: funcy>=1.14 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.0)
# Requirement already satisfied: grandalf<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.8)
# Requirement already satisfied: gto<2,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.9.0)
# Requirement already satisfied: hydra-core>=1.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.3.3)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.0.10)
# Requirement already satisfied: kombu in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (5.6.2)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (3.6.1)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.3.1)
# Requirement already satisfied: packaging>=19 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (26.2)
# Requirement already satisfied: pathspec<2,>=0.10.3 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.1.1)
# Requirement already satisfied: platformdirs<5,>=3.1.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (4.10.0)
# Requirement already satisfied: psutil>=5.8 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (5.9.5)
# Requirement already satisfied: pydot>=1.2.4 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (4.0.1)
# Requirement already satisfied: pygtrie>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.5.0)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (3.3.2)
# Requirement already satisfied: requests>=2.22 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (2.34.2)
# Requirement already satisfied: rich>=12 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (15.0.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.19.1)
# Requirement already satisfied: scmrepo<4,>=3.5.2 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (3.6.2)
# Requirement already satisfied: shortuuid>=0.5 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.0.13)
# Requirement already satisfied: shtab<2,>=1.3.4 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (1.8.0)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.10.0)
# Requirement already satisfied: tomlkit>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.15.0)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (4.67.3)
# Requirement already satisfied: voluptuous>=0.11.7 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (0.16.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (4.0)
# Requirement already satisfied: dvc-gdrive<4,>=3 in /usr/local/lib/python3.12/dist-packages (from dvc[gdrive]) (3.0.1)
# Requirement already satisfied: dictdiffer>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.19.0,>=3.18.2->dvc[gdrive]) (0.9.0)
# Requirement already satisfied: diskcache>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.19.0,>=3.18.2->dvc[gdrive]) (5.6.3)
# Requirement already satisfied: sqltrie<1,>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.19.0,>=3.18.2->dvc[gdrive]) (0.11.2)
# Requirement already satisfied: orjson<4,>=3 in /usr/local/lib/python3.12/dist-packages (from dvc-data<3.19.0,>=3.18.2->dvc[gdrive]) (3.11.9)
# Requirement already satisfied: pydrive2>=1.19.0 in /usr/local/lib/python3.12/dist-packages (from pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.21.3)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from dvc-http>=2.29.0->dvc[gdrive]) (2.9.1)
# Requirement already satisfied: billiard<5.0,>=4.2.1 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (4.2.4)
# Requirement already satisfied: vine<6.0,>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (5.1.0)
# Requirement already satisfied: click<9.0,>=8.1.2 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (8.4.1)
# Requirement already satisfied: click-didyoumean>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (0.3.1)
# Requirement already satisfied: click-repl>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (0.3.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (1.1.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (2.9.0.post0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.12/dist-packages (from celery->dvc[gdrive]) (5.3.1)
# Requirement already satisfied: atpublic in /usr/local/lib/python3.12/dist-packages (from flufl.lock<10,>=8.1.0->dvc[gdrive]) (7.0.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.4)
# Requirement already satisfied: pydantic>=2 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (2.14.2)
# Requirement already satisfied: semver>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (3.0.4)
# Requirement already satisfied: typer>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gto<2,>=1.6.0->dvc[gdrive]) (0.25.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.1->dvc[gdrive]) (4.9.3)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.12/dist-packages (from iterative-telemetry>=0.0.7->dvc[gdrive]) (1.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from iterative-telemetry>=0.0.7->dvc[gdrive]) (3.29.2)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /usr/local/lib/python3.12/dist-packages (from kombu->dvc[gdrive]) (5.3.1)
# Requirement already satisfied: tzdata>=2025.2 in /usr/local/lib/python3.12/dist-packages (from kombu->dvc[gdrive]) (2026.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->dvc[gdrive]) (6.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc[gdrive]) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc[gdrive]) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc[gdrive]) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /usr/local/lib/python3.12/dist-packages (from requests>=2.22->dvc[gdrive]) (2026.6.17)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->dvc[gdrive]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12->dvc[gdrive]) (2.20.0)
# Requirement already satisfied: gitpython>3 in /usr/local/lib/python3.12/dist-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (3.1.50)
# Requirement already satisfied: pygit2>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (1.19.3)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /usr/local/lib/python3.12/dist-packages (from scmrepo<4,>=3.5.2->dvc[gdrive]) (2.23.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from zc.lockfile>=1.2.1->dvc[gdrive]) (75.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (3.14.1)
# Requirement already satisfied: cryptography>=39.0 in /usr/local/lib/python3.12/dist-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (43.0.3)
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from asyncssh<3,>=2.13.1->scmrepo<4,>=3.5.2->dvc[gdrive]) (4.15.0)
# Requirement already satisfied: prompt-toolkit>=3.0.36 in /usr/local/lib/python3.12/dist-packages (from click-repl>=0.2.0->celery->dvc[gdrive]) (3.0.52)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython>3->scmrepo<4,>=3.5.2->dvc[gdrive]) (4.0.12)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12->dvc[gdrive]) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2->gto<2,>=1.6.0->dvc[gdrive]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings>=2->gto<2,>=1.6.0->dvc[gdrive]) (1.2.2)
# Requirement already satisfied: google-api-python-client>=1.12.5 in /usr/local/lib/python3.12/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.197.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.1.3)
# Requirement already satisfied: pyOpenSSL<=24.2.1,>=19.1.0 in /usr/local/lib/python3.12/dist-packages (from pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (24.2.1)
# Requirement already satisfied: cffi>=2.0 in /usr/local/lib/python3.12/dist-packages (from pygit2>=1.14.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->celery->dvc[gdrive]) (1.17.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc[gdrive]) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.4.1->gto<2,>=1.6.0->dvc[gdrive]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->aiohttp-retry>=2.5.0->dvc-http>=2.29.0->dvc[gdrive]) (1.24.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0->pygit2>=1.14.0->scmrepo<4,>=3.5.2->dvc[gdrive]) (3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<4,>=3.5.2->dvc[gdrive]) (5.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/lib/python3/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.20.2)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.55.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.2.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.6.3)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (0.4.2)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from oauth2client>=4.0.0->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (4.9.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit>=3.0.36->click-repl>=0.2.0->celery->dvc[gdrive]) (0.8.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (6.33.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.5->pydrive2>=1.19.0->pydrive2[fsspec]>=1.19.0->dvc-gdrive<4,>=3->dvc[gdrive]) (1.28.0)

# %%
# Reinstall scikit-learn and its dependencies to resolve binary incompatibility
# Reinstall numpy, scipy, and seaborn to resolve binary incompatibility issues
# When finished, go to manage session and terminate session before running notebook again
# !pip install --upgrade --force-reinstall numpy scipy seaborn
# !pip install --upgrade --force-reinstall scikit-learn
# Out:
# Collecting numpy
#   Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting scipy
#   Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.7 MB/s eta 0:00:00
# Collecting matplotlib!=3.6.1,>=3.4 (from seaborn)
#   Using cached matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
# Collecting contourpy>=1.0.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting packaging>=20.0 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pillow>=9 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 18.2 MB/s eta 0:00:00
# Using cached matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
# Downloading pandas-3.0.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 206.3 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
# Using cached kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached packaging-26.2-py3-none-any.whl (100 kB)
# Using cached pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, pyparsing, pillow, packaging, numpy, kiwisolver, fonttools, cycler, scipy, python-dateutil, contourpy, pandas, matplotlib, seaborn
#   Attempting uninstall: six
#     Found existing installation: six 1.17.0
#     Uninstalling six-1.17.0:
#       Successfully uninstalled six-1.17.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.3.2
#     Uninstalling pyparsing-3.3.2:
#       Successfully uninstalled pyparsing-3.3.2
#   Attempting uninstall: pillow
#     Found existing installation: pillow 12.2.0
#     Uninstalling pillow-12.2.0:
#       Successfully uninstalled pillow-12.2.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 26.2
#     Uninstalling packaging-26.2:
#       Successfully uninstalled packaging-26.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
#   Attempting uninstall: kiwisolver
#     Found existing installation: kiwisolver 1.5.0
#     Uninstalling kiwisolver-1.5.0:
#       Successfully uninstalled kiwisolver-1.5.0
#   Attempting uninstall: fonttools
#     Found existing installation: fonttools 4.63.0
#     Uninstalling fonttools-4.63.0:
#       Successfully uninstalled fonttools-4.63.0
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.18.0
#     Uninstalling scipy-1.18.0:
#       Successfully uninstalled scipy-1.18.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0.post0
#     Uninstalling python-dateutil-2.9.0.post0:
#       Successfully uninstalled python-dateutil-2.9.0.post0
#   Attempting uninstall: contourpy
#     Found existing installation: contourpy 1.3.3
#     Uninstalling contourpy-1.3.3:
#       Successfully uninstalled contourpy-1.3.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.3
#     Uninstalling pandas-2.3.3:
#       Successfully uninstalled pandas-2.3.3
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.11.0
#     Uninstalling matplotlib-3.11.0:
#       Successfully uninstalled matplotlib-3.11.0
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.14.0 requires pandas<3, but you have pandas 3.0.3 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.55.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.0 numpy-2.4.6 packaging-26.2 pandas-3.0.3 pillow-12.2.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 scipy-1.18.0 seaborn-0.13.2 six-1.17.0
# Collecting scikit-learn
#   Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.24.1 (from scikit-learn)
#   Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Using cached narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached narwhals-2.22.1-py3-none-any.whl (454 kB)
# Using cached numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
# Using cached scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, narwhals, joblib, scipy, scikit-learn
#   Attempting uninstall: threadpoolctl
#     Found existing installation: threadpoolctl 3.6.0
#     Uninstalling threadpoolctl-3.6.0:
#       Successfully uninstalled threadpoolctl-3.6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.4.6
#     Uninstalling numpy-2.4.6:
#       Successfully uninstalled numpy-2.4.6
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 2.22.1
#     Uninstalling narwhals-2.22.1:
#       Successfully uninstalled narwhals-2.22.1
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.3
#     Uninstalling joblib-1.5.3:
#       Successfully uninstalled joblib-1.5.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.18.0
#     Uninstalling scipy-1.18.0:
#       Successfully uninstalled scipy-1.18.0
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.9.0
#     Uninstalling scikit-learn-1.9.0:
#       Successfully uninstalled scikit-learn-1.9.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mlflow 3.14.0 requires pandas<3, but you have pandas 3.0.3 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.55.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed joblib-1.5.3 narwhals-2.22.1 numpy-2.4.6 scikit-learn-1.9.0 scipy-1.18.0 threadpoolctl-3.6.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### What is MLflow?
#
# MLflow is an open-source platform for managing the end-to-end machine learning lifecycle. It addresses four primary functions:
#
# 1.  **Tracking:** Record and query experiments (code, data, configuration, results).
# 2.  **Projects:** Package ML code in a reusable, reproducible form.
# 3.  **Models:** Manage ML models from various libraries and deploy them to diverse serving platforms.
# 4.  **Model Registry:** Store, annotate, discover, and manage models in a central repository.
#
# To view the MLflow UI, you would typically run `!mlflow ui` in your terminal or a separate Colab cell if you have a local setup or a tracking server. In Colab, if you want to run `mlflow ui` within the notebook, you would typically need to expose a port, which is a bit more involved. For now, the focus is on logging.
#
# ### What is DVC?
#
# DVC (Data Version Control) is an open-source version control system for machine learning projects. It makes ML projects reproducible by tracking machine learning models and datasets. DVC works alongside Git, allowing you to manage large files and directories as part of your Git repository without committing them directly to Git.
#
# Key features include:
#
# 1.  **Data Versioning:** Version large datasets and models.
# 2.  **Experiment Management:** Track experiments by linking code, data, and models.
# 3.  **Reproducibility:** Recreate experiments by checking out specific data and model versions.
# 4.  **Pipeline Management:** Define and run data processing and ML pipelines.

# %%
# Install pyngrok to tunnel the MLflow UI
# !pip install pyngrok
# Out:
# Collecting pyngrok
#   Downloading pyngrok-8.1.2-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Downloading pyngrok-8.1.2-py3-none-any.whl (25 kB)
# Installing collected packages: pyngrok
# Successfully installed pyngrok-8.1.2

# %%
import os
from google.colab import userdata

# Get your ngrok authtoken from Colab secrets
NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')

# Set the authtoken
# !ngrok authtoken {NGROK_AUTH_TOKEN}

print("ngrok authtoken configured.")
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# ngrok authtoken configured.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Installing DVC
#
# Let's install DVC. We'll use `dvc[gdrive]` for Google Drive integration, which is useful in Colab.

# %% [markdown]
# ### Basic DVC Usage
#
# To use DVC, you'll typically initialize a Git repository first, and then a DVC repository within it. For simplicity in Colab, we can skip the Git initialization if you only want to version data locally or with Google Drive as a remote. Let's set up a DVC remote to your Google Drive to store versioned data.
#
# **Note:** You need to have git installed and initialize a git repo for DVC to work fully. If you haven't, please run !apt-get update && apt-get install git -y and then !git init in a separate cell before running the DVC commands.
#
# **Setting up DVC with Google Drive:**

# %% [markdown]
# ### Connecting Colab Git to GitHub
#
# To connect your Colab environment to your GitHub repository, you'll need to configure Git with your user information and then either use an SSH key or a Personal Access Token (PAT) for authentication. Using a PAT is often simpler in Colab.
#
# #### 1. Configure Git User Information

# %%
# Replace with your GitHub email and username
# !git config --global user.email "isaac_adebayojr@gmail.com"
# !git config --global user.name "isaacadebayo"

print("Git user configured.")
# Out:
# Git user configured.

# %% [markdown]
# #### 2. Authenticate with GitHub using a Personal Access Token (PAT)
#
# GitHub requires authentication for many Git operations. A Personal Access Token (PAT) is a secure way to do this without exposing your password. If you don't have one, you can create it in your GitHub settings (Settings > Developer settings > Personal access tokens > Tokens (classic)). Give it the `repo` scope.
#
# Once you have your PAT, you can use it to clone your repository.

# %%
# Store your GitHub PAT securely in Colab Secrets
# Click on the '🔑' icon on the left panel, add a new secret named 'GH_TOKEN' and paste your PAT there.
from google.colab import userdata
import os

# Get the PAT from Colab secrets
GH_TOKEN = userdata.get('GH_TOKEN')

# Set it as an environment variable (optional, but good practice if cloning private repos)
os.environ['GH_TOKEN'] = GH_TOKEN

print("GitHub Token retrieved. You can now use it for cloning private repositories.")
# Out:
# GitHub Token retrieved. You can now use it for cloning private repositories.

# %% [markdown]
# #### 3. Clone your GitHub Repository
#
# Now you can clone your repository. For private repositories, you'll include your PAT in the URL.

# %%
# Replace 'your_username' and 'your_repository' with your actual GitHub details.
# For a public repository:
# !git clone https://github.com/isaacadebayo/Predictive-Analytics-Public-Datasets.git

# For a private repository using PAT:
# This uses the GH_TOKEN environment variable
# !git clone https://{GH_TOKEN}@github.com/isaacadebayo/Predictive-Analytics-Public-Datasets

# Change into your repository directory to perform Git operations
# %cd Predictive-Analytics-Public-Datasets

print("Repository cloned. You are now in the repository directory.")
# Out:
# Cloning into 'Predictive-Analytics-Public-Datasets'...
# remote: Enumerating objects: 244, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 244 (delta 37), reused 35 (delta 4), pack-reused 138 (from 1)
# Receiving objects: 100% (244/244), 30.32 MiB | 32.78 MiB/s, done.
# Resolving deltas: 100% (110/110), done.
# fatal: destination path 'Predictive-Analytics-Public-Datasets' already exists and is not an empty directory.
# /content/Predictive-Analytics-Public-Datasets/Predictive-Analytics-Public-Datasets
# Repository cloned. You are now in the repository directory.

# %%
# Initialize DVC within the current directory (which is the cloned Git repo)
# !dvc init

# Configure Google Drive as a remote storage (replace 'dvc_storage' with your desired folder name in Google Drive)
# !dvc remote add -d gdrive_remote gdrive://MyDrive/dvc_storage
# !dvc remote add -d gcs_remote gs://my-agentic-chatbot-data-lake

# Create a data directory within the Git repository if it doesn't exist
# !mkdir -p data

# Copy the data file into the Git repository's data directory
# This ensures the .dvc file (created by dvc add) will be within the Git repo
# !cp /content/drive/MyDrive/aapl_stock_prices.csv data/aapl_stock_prices.csv

# Add a data file to DVC. This will create a .dvc file at data/aapl_stock_prices.csv.dvc
# !dvc add data/aapl_stock_prices.csv

# To commit the .dvc file to Git (requires Git setup, which is already done)
# Now git will find the .dvc file within its repository's working directory
# !git add data/aapl_stock_prices.csv.dvc
# !git commit -m "Add aapl_stock_prices.csv to DVC"

print("DVC setup complete. Your data file is now versioned with DVC and stored in Google Drive.")
print("You can push/pull changes using: !dvc push and !dvc pull")
# Out:
# /bin/bash: line 1: dvc: command not found
# /bin/bash: line 1: dvc: command not found
# /bin/bash: line 1: dvc: command not found
# /bin/bash: line 1: dvc: command not found
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# DVC setup complete. Your data file is now versioned with DVC and stored in Google Drive.
# You can push/pull changes using: !dvc push and !dvc pull

# %%
# Stage all changes in the current directory
# !git add .

# Commit the staged changes with a message
# Replace 'Your insightful commit message' with a description of your changes
# !git commit -m "Testing commit from colab to github"

# Push the changes to the 'main' branch of your remote repository
# This uses the GH_TOKEN environment variable for authentication
# !git push https://{GH_TOKEN}@github.com/isaacadebayo/Predictive-Analytics-Public-Datasets.git main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
print('Contents of the cloned repository:')
# !ls -F
# Out:
# Contents of the cloned repository:
#  Apple_Stock_prediction.ipynb
#  Apple_Stock_prediction_timeseries_split_fold4.ipynb
#  Apple_Stock_prediction_timeseries_split.ipynb
#  data/
# 'Fraud_detection_highEvalMatrix_(1).ipynb'
#  Fraud_detection_highEvalMatrix_FINAL.ipynb
#  Fraud_detection_highEvalMatrix.ipynb
#  Fraud_detection.ipynb
# 'GRADIO_Multimodal_Chatbot_Longevity_ No_API_KEY.ipynb'
#  Image_Generation_using_gpt_image_1.ipynb
#  mlartifacts/
#  Model_finetuning_mistral_ai.ipynb
#  project/
#  RAG_Finanicial_Audio_Chatbot_Original_No_API_KEY.ipynb
#  RAG_Finanicial_Chatbot_Original_NoAPI_Key.ipynb
#  README.md
#  response.mp3
#  Time_Series_Financial_NYSE.ipynb
#  Unsupervised_learning_Clustering_Credit_Card_Analysis.ipynb
#  Visual_Transformer_and_CNN.ipynb
#  visual_transformer_and_cnn.py
#  WHISPER_Audio_Transformer.ipynb

# %% [markdown]
# After these steps, you can use standard `!git` commands (e.g., `!git add .`, `!git commit -m "Message"`, `!git push origin main`) to interact with your GitHub repository from Colab.

# %% [markdown]
# ### More on DVC
#
# *   DVC and dataset integrity alteration: DVC focuses on dataset integrity and preventing alteration. Its core purpose is to version control data just like Git version controls code
# *   Purpose of .dvc file with cloud storage . dvc does not store the actual data itself instead it is a small human readable text file that contains metadata about data file such as path of originl data file, hash checksum of the data file and a pointer to the locaiton of the actual data in my remote storage

# %%
stocks = pd.read_csv('/content/drive/MyDrive/aapl_stock_prices.csv')
stocks.head()
# Out:
#          Date      Open      High       Low     Close     Volume
# 0  1980-12-12  0.098297  0.098725  0.098297  0.098297  469033600
# 1  1980-12-15  0.093597  0.093597  0.093169  0.093169  175884800
# 2  1980-12-16  0.086758  0.086758  0.086331  0.086331  105728000
# 3  1980-12-17  0.088468  0.088895  0.088468  0.088468   86441600
# 4  1980-12-18  0.091032  0.091460  0.091032  0.091032   73449600

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Moving average price

# %%
stocks['Moving_Average'] = stocks['Close'].rolling(window=50).mean()

stocks
# Out:
#              Date        Open        High         Low       Close     Volume  \
# 0      1980-12-12    0.098297    0.098725    0.098297    0.098297  469033600
# 1      1980-12-15    0.093597    0.093597    0.093169    0.093169  175884800
# 2      1980-12-16    0.086758    0.086758    0.086331    0.086331  105728000
# 3      1980-12-17    0.088468    0.088895    0.088468    0.088468   86441600
# 4      1980-12-18    0.091032    0.091460    0.091032    0.091032   73449600
# ...           ...         ...         ...         ...         ...        ...
# 11402  2026-03-12  258.660004  258.950012  254.179993  255.759995   40794000
# 11403  2026-03-13  255.479996  256.329987  249.520004  250.119995   36930000
# 11404  2026-03-16  252.110001  253.889999  249.880005  252.820007   32074200
# 11405  2026-03-17  252.960007  255.130005  252.179993  254.229996   32361600
# 11406  2026-03-18  252.625000  254.940002  249.000000  249.940002   34652568
#
#        Moving_Average
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 11402      263.034650
# 11403      262.580556
# 11404      262.204839
# 11405      261.874306
# 11406      261.532903
#
# [11407 rows x 7 columns]

# %% [markdown]
# Difference in price

# %%
delta = stocks['Close'].diff()
delta
# Out:
# 0             NaN
# 1       -0.005128
# 2       -0.006838
# 3        0.002137
# 4        0.002565
#            ...
# 11402   -5.050003
# 11403   -5.639999
# 11404    2.700012
# 11405    1.409988
# 11406   -4.289993
# Name: Close, Length: 11407, dtype: float64

# %% [markdown]
# Separate calculated gain and losses

# %%
gain = delta.clip(lower=0)
loss = -1 * delta.clip(upper=0)

# %% [markdown]
# Calculate Exponential moving average

# %%
avg_gain = gain.ewm(com=14, min_periods=14, adjust=False).mean()
avg_loss = loss.ewm(com=14, min_periods=14, adjust=False).mean()

avg_loss
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 11402    1.726921
# 11403    1.987793
# 11404    1.855273
# 11405    1.731588
# 11406    1.902149
# Name: Close, Length: 11407, dtype: float64

# %%
rs = avg_gain / avg_loss
rsi = 100 - (100 / (1 + rs))

stocks['RSI'] = rsi
stocks.head()
# Out:
#          Date      Open      High       Low     Close     Volume  \
# 0  1980-12-12  0.098297  0.098725  0.098297  0.098297  469033600
# 1  1980-12-15  0.093597  0.093597  0.093169  0.093169  175884800
# 2  1980-12-16  0.086758  0.086758  0.086331  0.086331  105728000
# 3  1980-12-17  0.088468  0.088895  0.088468  0.088468   86441600
# 4  1980-12-18  0.091032  0.091460  0.091032  0.091032   73449600
#
#    Moving_Average  RSI
# 0             NaN  NaN
# 1             NaN  NaN
# 2             NaN  NaN
# 3             NaN  NaN
# 4             NaN  NaN

# %% [markdown]
# Drop first 50 rows to incorporate moving average column and prevent skewing the data

# %%
stocks.isna().sum()
# Out:
# Date               0
# Open               0
# High               0
# Low                0
# Close              0
# Volume             0
# Moving_Average    49
# RSI               14
# dtype: int64

# %%
stocks.drop(index=stocks.index[:50], inplace=True)
stocks.head()
# Out:
#           Date      Open      High       Low     Close    Volume  \
# 50  1981-02-25  0.086331  0.086758  0.086331  0.086331  19488000
# 51  1981-02-26  0.087613  0.088040  0.087613  0.087613  10841600
# 52  1981-02-27  0.090605  0.091460  0.090605  0.090605  14761600
# 53  1981-03-02  0.091032  0.091460  0.091032  0.091032  11760000
# 54  1981-03-03  0.090178  0.090178  0.089750  0.089750  16172800
#
#     Moving_Average        RSI
# 50        0.101298  38.088629
# 51        0.101187  39.855881
# 52        0.101272  43.863024
# 53        0.101324  44.429548
# 54        0.101298  43.033586

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11357 entries, 50 to 11406
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            11357 non-null  object
#  1   Open            11357 non-null  float64
#  2   High            11357 non-null  float64
#  3   Low             11357 non-null  float64
#  4   Close           11357 non-null  float64
#  5   Volume          11357 non-null  int64
#  6   Moving_Average  11357 non-null  float64
#  7   RSI             11357 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 709.9+ KB

# %%
if 'Date' in stocks.columns:
    stocks['Date'] = pd.to_datetime(stocks['Date'])
    stocks = stocks.set_index('Date')
stocks.Close.plot(figsize=(18,7), linewidth=1, c='g')
# Out:
# <Axes: xlabel='Date'>

# %%
# Create lagged sequences
window_size = 10

#perm = np.arange(window_size)
perm = np.random.permutation(np.arange(window_size))

X, y = [], []
dates = []
for i in range(len(stocks) - window_size):
    X.append(stocks.iloc[i:i+window_size].values)
    # Predict only the 'close' price (index 1) for y
    y.append(stocks.iloc[i+window_size, 1])
    dates.append(stocks.index[i+window_size])

X = np.array(X)
y = np.array(y)
dates = np.array(dates)

print(f"X shape: {X.shape}, y shape: {y.shape}")
# Out:
# X shape: (11347, 10, 7), y shape: (11347,)

# %%
# one temporal split, used by everyone
split_idx    = int(len(X) * 0.8)
X_train_3d   = X[:split_idx]       # for LSTM (3D)
X_test_3d    = X[split_idx:]
X_train_2d   = X_train_3d.reshape(X_train_3d.shape[0], -1)  # for sklearn + Dense
X_test_2d    = X_test_3d.reshape(X_test_3d.shape[0], -1)
y_train      = y[:split_idx]
y_test       = y[split_idx:]
dates_train  = dates[:split_idx]
dates_test   = dates[split_idx:]

print(f"Train: X={X_train_3d.shape}, y={y_train.shape}")
print(f"Test:  X={X_test_3d.shape}, y={y_test.shape}")
print(f"Train: X={X_train_2d.shape}, y={y_train.shape}")
print(f"Test:  X={X_test_2d.shape}, y={y_test.shape}")
print(f"Train: X={dates_train.shape}, y={y_train.shape}")
print(f"Test:  X={dates_test.shape}, y={y_test.shape}")
# Out:
# Train: X=(9077, 10, 7), y=(9077,)
# Test:  X=(2270, 10, 7), y=(2270,)
# Train: X=(9077, 70), y=(9077,)
# Test:  X=(2270, 70), y=(2270,)
# Train: X=(9077,), y=(9077,)
# Test:  X=(2270,), y=(2270,)

# %%
from sklearn.preprocessing import MinMaxScaler
# one scaler, fit on train only, used by Keras pipelines
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_train_scaled_2d = scaler_X.fit_transform(X_train_2d)
X_test_scaled_2d   = scaler_X.transform(X_test_2d)
y_train_scaled = scaler_y.fit_transform(y_train.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.reshape(-1,1))
# reshape scaled 2D back to 3D
X_train_scaled_3d = X_train_scaled_2d.reshape(X_train_3d.shape)
X_test_scaled_3d  = X_test_scaled_2d.reshape(X_test_3d.shape)

# %%
plt.figure(figsize=(7,3))
# y_train and y_test are now 1D arrays
plt.plot( dates_train, y_train, 'b', label='Train' );
plt.plot( dates_test, y_test, 'r', label='Test' );
plt.legend()

# %%
'''# Simple index-based split
split_idx = int(len(X) * 0.9)
X_train, y_train, dates_train = X[:split_idx], y[:split_idx], dates[:split_idx]
X_test, y_test, dates_test = X[split_idx:], y[split_idx:], dates[split_idx:]

# Reshape X_train and X_test to be 2D for scikit-learn models
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

print(f"Train: X={X_train.shape}, y={y_train.shape}")
print(f"Test:  X={X_test.shape}, y={y_test.shape}")'''
# Out:
# '# Simple index-based split\nsplit_idx = int(len(X) * 0.9)\nX_train, y_train, dates_train = X[:split_idx], y[:split_idx], dates[:split_idx]\nX_test, y_test, dates_test = X[split_idx:], y[split_idx:], dates[split_idx:]\n\n# Reshape X_train and X_test to be 2D for scikit-learn models\nX_train = X_train.reshape(X_train.shape[0], -1)\nX_test = X_test.reshape(X_test.shape[0], -1)\n\nprint(f"Train: X={X_train.shape}, y={y_train.shape}")\nprint(f"Test:  X={X_test.shape}, y={y_test.shape}")'

# %% [markdown]
# # Cross Validation

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

models = [
    LinearRegression(),
    KNeighborsRegressor(n_neighbors=4, weights='uniform'),
    RandomForestRegressor(n_estimators=10, max_depth=5),
    RandomForestRegressor(n_estimators=30, max_depth=10),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=2),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3),
    GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=5),
]

# %%
from sklearn.model_selection import cross_val_score, KFold, TimeSeriesSplit

#kf = KFold(n_splits=5, shuffle=True)
kf = TimeSeriesSplit(n_splits=5)

# Reshape X to be 2-dimensional for scikit-learn models
X_2d = X.reshape(X.shape[0], -1)

for m in models:
    print(m)

    cv_scores = -cross_val_score(m, X_2d, y, cv=kf, scoring='neg_mean_absolute_percentage_error')
    cv_scores = pd.DataFrame(cv_scores)
    display(cv_scores.describe().T)

    print()
# end
# Out:
# LinearRegression()
#    count      mean       std       min       25%       50%       75%      max
# 0    5.0  0.013172  0.004354  0.008162  0.010175  0.013509  0.014532  0.01948
# KNeighborsRegressor(n_neighbors=4)
#    count      mean       std      min       25%       50%       75%       max
# 0    5.0  0.681119  0.222503  0.41377  0.477388  0.771587  0.824351  0.918497
# RandomForestRegressor(max_depth=5, n_estimators=10)
#    count      mean       std      min       25%       50%       75%       max
# 0    5.0  0.327802  0.256863  0.02843  0.069331  0.465556  0.526246  0.549446
# RandomForestRegressor(max_depth=10, n_estimators=30)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.327723  0.256754  0.028258  0.069223  0.466569  0.530951  0.543616
# GradientBoostingRegressor(max_depth=2)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.325392  0.253766  0.028452  0.070646  0.465934  0.519843  0.542088
# GradientBoostingRegressor()
#    count      mean       std      min       25%       50%       75%       max
# 0    5.0  0.325369  0.253862  0.03013  0.068594  0.466211  0.518374  0.543535
# GradientBoostingRegressor(max_depth=5)
#    count      mean       std       min       25%       50%       75%       max
# 0    5.0  0.327244  0.255185  0.029499  0.070091  0.467925  0.526645  0.542061

# %% [markdown]
# # Grid SearchCV

# %%
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

# Define models and their parameter grids
param_grids = {
    "KNeighborsRegressor": (
        KNeighborsRegressor(),
        {
            "n_neighbors": [1, 5, 10, 20, 50],
            "weights": ["uniform", "distance"]
        }
    ),

    "RandomForestRegressor": (
        RandomForestRegressor(),
        {
            "n_estimators": [10, 50, 100],
            "max_depth": [3, 5, 10],
            "min_samples_split": [2, 5, 10],
            'min_samples_leaf': [1, 2, 5, 10]
        }
    ),

    "GradientBoostingRegressor": (
        GradientBoostingRegressor(),
        {
            "n_estimators": [50, 100, 200],
            "learning_rate": [0.01, 0.1, 0.2],
            "max_depth": [2, 3, 5],
            'min_samples_leaf': [1, 2, 5, 10]
        }
    )
}

# Define cross-validation strategy
#kf = KFold(n_splits=5, shuffle=True)
kf = TimeSeriesSplit(n_splits=5)

# Store results
results = []

# Perform GridSearchCV for each model
for name, (model, param_grid) in param_grids.items():
    print(f"Performing GridSearchCV for {name}...")

    grid_search = GridSearchCV(model, param_grid, cv=kf, scoring="neg_mean_absolute_percentage_error", n_jobs=-1)
    grid_search.fit(X_2d, y)

    best_params = grid_search.best_params_
    best_score = grid_search.best_score_

    results.append({"Model": name, "Best Score": best_score, "Best Params": best_params})
# end

results
# Out:
# Performing GridSearchCV for KNeighborsRegressor...
# Performing GridSearchCV for RandomForestRegressor...
# Performing GridSearchCV for GradientBoostingRegressor...
# [{'Model': 'KNeighborsRegressor',
#   'Best Score': np.float64(-0.6663154674458628),
#   'Best Params': {'n_neighbors': 50, 'weights': 'uniform'}},
#  {'Model': 'RandomForestRegressor',
#   'Best Score': np.float64(-0.3263778970010806),
#   'Best Params': {'max_depth': 10,
#    'min_samples_leaf': 1,
#    'min_samples_split': 5,
#    'n_estimators': 10}},
#  {'Model': 'GradientBoostingRegressor',
#   'Best Score': np.float64(-0.3239171941938104),
#   'Best Params': {'learning_rate': 0.2,
#    'max_depth': 2,
#    'min_samples_leaf': 1,
#    'n_estimators': 200}}]

# %% [markdown]
# # Feature Importance

# %%
# Fit a Random Forest model
rf = RandomForestRegressor(n_estimators=1000)
rf.fit(X_2d, y)

# Generate feature names for X_2d
original_features = stocks.columns.tolist()
feature_names_for_X_2d = []
for lag in range(window_size, 0, -1): # Lags from window_size down to 1
    for col in original_features:
        feature_names_for_X_2d.append(f'{col}_lag{lag}')

# Get feature importances
importances = pd.Series(rf.feature_importances_, index=feature_names_for_X_2d).sort_values(ascending=False)
importances = importances[:20]

# Get the names of the selected features
features_rf = importances.index.tolist()

# Create a DataFrame from X_2d with the correct column names for easier slicing
X_2d_df = pd.DataFrame(X_2d, columns=feature_names_for_X_2d)

# Select only the important features from X_2d_df
X_pars = X_2d_df[features_rf]

importances
# Out:
# Close_lag1              0.524875
# Low_lag1                0.231058
# High_lag1               0.091586
# Close_lag2              0.033692
# Low_lag2                0.033520
# Close_lag3              0.017649
# Open_lag1               0.016113
# Low_lag3                0.012306
# High_lag2               0.010730
# Open_lag2               0.005420
# Moving_Average_lag7     0.001887
# Moving_Average_lag8     0.001884
# Open_lag3               0.001869
# Low_lag4                0.001804
# High_lag3               0.001562
# High_lag5               0.001065
# Moving_Average_lag2     0.001060
# Close_lag4              0.001033
# High_lag10              0.001002
# Moving_Average_lag10    0.000989
# dtype: float64

# %% [markdown]
# # KERAS

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (7.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.81.0)
# Requirement already satisfied: keras>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Downloading wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.5.20)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 7.0 MB/s eta 0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.6 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 178.7 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 155.7 MB/s eta 0:00:00
# Downloading wheel-0.47.0-py3-none-any.whl (32 kB)
# Installing collected packages: libclang, flatbuffers, wheel, h5py, google_pasta, astunparse, tensorflow
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.16.0
#     Uninstalling h5py-3.16.0:
#       Successfully uninstalled h5py-3.16.0
# Successfully installed astunparse-1.6.3 flatbuffers-25.12.19 google_pasta-0.2.0 h5py-3.14.0 libclang-18.1.1 tensorflow-2.21.0 wheel-0.47.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def build_model( X_train, epochs, batch_size, decay_frac, initial_learning_rate, dropout_rate ):

    # Create model
    model = Sequential([
        Input(shape=X_train.shape[1]),
        Dense(20, activation='relu'),
        Dropout(dropout_rate),
        Dense(20, activation='relu'),
        Dropout(dropout_rate),
        Dense(20, activation='relu'),
        Dense(1, activation='relu'),
    ])

    # define training parameters
    decay_epochs    = int( epochs * decay_frac )
    n_train         = X_train.shape[0]
    steps_per_epoch = int( np.ceil( n_train / batch_size ) )
    decay_steps     = decay_epochs * steps_per_epoch

    lr_schedule_poly = PolynomialDecay(
        initial_learning_rate=initial_learning_rate,
        end_learning_rate=0.001,
        decay_steps=decay_steps,
        power=2.0
    )

    # Define the optimizer with a custom learning rate
    optimizer = Adam(
        learning_rate=lr_schedule_poly,
    )

    # Compile model
    model.compile(
        optimizer=optimizer,
        loss='mae'
    )

    return model
# end
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
from sklearn.model_selection import KFold, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler # Import MinMaxScaler

# Re-defining build_model with the fix for the Input layer
from keras.models import Sequential
from keras.layers import *
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

def build_model( X_train, epochs, batch_size, decay_frac, initial_learning_rate, dropout_rate ):

    # Create model
    model = Sequential([
        Input(shape=(X_train.shape[1], X_train.shape[2])), # Corrected: Input layer now expects 3D shape
        Flatten(), # Added: Flatten the input for Dense layers
        Dense(20, activation='relu'),
        Dropout(dropout_rate),
        Dense(20, activation='relu'),
        Dropout(dropout_rate),
        Dense(20, activation='relu'),
        Dense(1, activation='linear'), # Changed activation to 'linear' for regression
    ])

    # define training parameters
    decay_epochs    = int( epochs * decay_frac )
    n_train         = X_train.shape[0]
    steps_per_epoch = int( np.ceil( n_train / batch_size ) )
    decay_steps     = decay_epochs * steps_per_epoch

    lr_schedule_poly = PolynomialDecay(
        initial_learning_rate=initial_learning_rate,
        end_learning_rate=0.001,
        decay_steps=decay_steps,
        power=2.0
    )

    # Define the optimizer with a custom learning rate
    optimizer = Adam(
        learning_rate=lr_schedule_poly,
    )

    # Compile model
    model.compile(
        optimizer=optimizer,
        loss='mae'
    )

    return model
# end

epochs                = 500
batch_size            = 256
decay_frac            = 0.8
dropout_rate          = 0.25
initial_learning_rate = 0.01

n_splits = 5
#kf = KFold(n_splits=n_splits, shuffle=True)
kf = TimeSeriesSplit(n_splits=n_splits)

train_mae_list = []
test_mae_list = []
train_r2_list = []
test_r2_list = []

fold = 1
for train_index, test_index in kf.split(X):
    print(f"Fold {fold}/{n_splits}")
    X_train_fold, X_test_fold = X[train_index], X[test_index]
    y_train_fold, y_test_fold = y[train_index], y[test_index]

    # Scale X_train_fold and y_train_fold for the neural network
    # Flatten X_train_fold and X_test_fold for scaling, then reshape back
    scaler_X = MinMaxScaler(feature_range=(0,1))
    X_train_flat = X_train_fold.reshape(X_train_fold.shape[0], -1)
    X_test_flat = X_test_fold.reshape(X_test_fold.shape[0], -1)

    X_train_scaled = scaler_X.fit_transform(X_train_flat)
    X_test_scaled = scaler_X.transform(X_test_flat)

    X_train_scaled = X_train_scaled.reshape(X_train_fold.shape)
    X_test_scaled = X_test_scaled.reshape(X_test_fold.shape)

    scaler_y = MinMaxScaler(feature_range=(0,1))
    y_train_scaled = scaler_y.fit_transform(y_train_fold.reshape(-1, 1))
    y_test_scaled = scaler_y.transform(y_test_fold.reshape(-1, 1))

    # Build a fresh model (which resets optimizer state including the learning rate schedule)
    model = build_model(
        X_train_scaled, # Changed to X_train_scaled (3D data for current fold)
        epochs,
        batch_size,
        decay_frac,
        initial_learning_rate,
        dropout_rate
    )

    # Early stopping callback
    early_stopping = EarlyStopping(
        monitor='val_loss',  # Monitor validation loss
        patience=100,          # Stop after 5 epochs without improvement
        restore_best_weights=True  # Restore the best weights after stopping
    )

    # Train the model
    history = model.fit(
        X_train_scaled, y_train_scaled, # Changed to X_train_scaled (3D data for current fold)
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_scaled, y_test_scaled), # Changed to X_test_scaled (3D data for current fold)
        verbose=0,
        callbacks=[early_stopping]
    )

    # Evaluate on training data
    y_train_pred_scaled = model.predict(X_train_scaled, verbose=0)
    y_train_pred = scaler_y.inverse_transform(y_train_pred_scaled) # Inverse transform predictions
    train_mae = mean_absolute_error(y_train_fold, y_train_pred)
    train_r2 = r2_score(y_train_fold, y_train_pred)

    # Evaluate on test data
    y_test_pred_scaled = model.predict(X_test_scaled, verbose=0)
    y_test_pred = scaler_y.inverse_transform(y_test_pred_scaled) # Inverse transform predictions
    test_mae = mean_absolute_error(y_test_fold, y_test_pred)
    test_r2 = r2_score(y_test_fold, y_test_pred)

    print("MAE:")
    print(f"  Train: {train_mae:.4f}")
    print(f"  Test:  {test_mae:.4f}")
    print("R^2:")
    print(f"  Train: {train_r2:.4f}")
    print(f"  Test:  {test_r2:.4f}")
    print()

    train_mae_list.append(train_mae)
    test_mae_list.append(test_mae)
    train_r2_list.append(train_r2)
    test_r2_list.append(test_r2)

    fold += 1
# end
# Out:
# Fold 1/5
# MAE:
#   Train: 0.0370
#   Test:  0.0989
# R^2:
#   Train: 0.6552
#   Test:  -1.1606
#
# Fold 2/5
# MAE:
#   Train: 0.0614
#   Test:  0.1014
# R^2:
#   Train: 0.6006
#   Test:  0.6137
#
# Fold 3/5
# MAE:
#   Train: 0.0840
#   Test:  1.3469
# R^2:
#   Train: 0.5719
#   Test:  0.5883
#
# Fold 4/5
# MAE:
#   Train: 0.3659
#   Test:  9.3518
# R^2:
#   Train: 0.8062
#   Test:  -0.0716
#
# Fold 5/5
# MAE:
#   Train: 1.9082
#   Test:  57.0255
# R^2:
#   Train: 0.8310
#   Test:  0.0958

# %% [markdown]
# # Model Creation

# %%
dropout_rate = 0.1

model_dense  = Sequential([
    Input(shape=(X_train_scaled_2d.shape[1],)), # Corrected input shape to match X_train_scaled_2d

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),

    Dense(16, activation='relu'),
    BatchNormalization(),
    Dropout(dropout_rate),

    Dense(8, activation='relu'),

    Dense(1, activation='linear'),
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.01)

# Compile model
model_dense .compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# Callback to reduce LR when a monitored metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',       # metric to monitor
    factor=0.5,               # factor by which to reduce the LR
    patience=50,              # number of epochs with no improvement after which LR will be reduced
    min_lr=1e-6,              # lower bound on the learning rate
    verbose=1                 # print when LR is reduced
)

model_dense .summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_20 (Dense)                │ (None, 32)             │         2,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_21 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 8)              │           136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,137 (12.25 KB)
#  Trainable params: 3,041 (11.88 KB)
#  Non-trainable params: 96 (384.00 B)

# %% [markdown]
# ### Re-scaling Data for `model_dense`
#
# The cross-validation loop in `cell_KDvNPcdiepgH` updated the `y_train_scaled` variable. To ensure consistent data cardinality for training `model_dense`, we need to re-scale the data (`X_train_2d`, `y_train`, `X_test_2d`, `y_test`) using the original `scaler_X` and `scaler_y` (fitted on the 80/20 split) immediately before training `model_dense`.

# %%
from sklearn.preprocessing import MinMaxScaler

# Re-initialize scalers (or re-use existing ones if already fitted on the correct split)
# scaler_X and scaler_y were defined and fitted in cell 'XlacRcBnxwXz' based on the initial 80/20 split.
# We will re-apply them to ensure consistency.

# Re-scale X_train_2d and X_test_2d
X_train_scaled_2d = scaler_X.transform(X_train_2d)
X_test_scaled_2d  = scaler_X.transform(X_test_2d)

# Re-scale y_train and y_test
y_train_scaled = scaler_y.transform(y_train.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.reshape(-1,1))

print(f"X_train_scaled_2d shape: {X_train_scaled_2d.shape}")
print(f"y_train_scaled shape: {y_train_scaled.shape}")
print(f"X_test_scaled_2d shape: {X_test_scaled_2d.shape}")
print(f"y_test_scaled shape: {y_test_scaled.shape}")

print("Data for model_dense re-scaled successfully.")
# Out:
# X_train_scaled_2d shape: (9077, 70)
# y_train_scaled shape: (9077, 1)
# X_test_scaled_2d shape: (2270, 70)
# y_test_scaled shape: (2270, 1)
# Data for model_dense re-scaled successfully.

# %%
history_dense = model_dense.fit(
    X_train_scaled_2d, y_train_scaled, # Use scaled 2D data
    epochs=150,
    batch_size=64,
    validation_data=(X_test_scaled_2d, y_test_scaled), # Use scaled 2D data for validation
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0563 - val_loss: 0.2792
# Epoch 2/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0196 - val_loss: 0.3766
# Epoch 3/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0162 - val_loss: 0.3173
# Epoch 4/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0148 - val_loss: 0.1495
# Epoch 5/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0145 - val_loss: 0.0693
# Epoch 6/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0120 - val_loss: 0.3932
# Epoch 7/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - val_loss: 0.5401
# Epoch 8/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0120 - val_loss: 0.1865
# Epoch 9/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - val_loss: 0.2892
# Epoch 10/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0118 - val_loss: 0.7912
# Epoch 11/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - val_loss: 0.7752
# Epoch 12/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0124 - val_loss: 0.7062
# Epoch 13/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0115 - val_loss: 0.7556
# Epoch 14/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0108 - val_loss: 0.1168
# Epoch 15/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - val_loss: 0.5296
# Epoch 16/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - val_loss: 0.1439
# Epoch 17/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0109 - val_loss: 0.2108
# Epoch 18/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - val_loss: 0.6199
# Epoch 19/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0107 - val_loss: 0.1139
# Epoch 20/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - val_loss: 0.2433
# Epoch 21/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - val_loss: 0.3322
# Epoch 22/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0092 - val_loss: 0.3301
# Epoch 23/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - val_loss: 0.5630
# Epoch 24/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - val_loss: 0.4280
# Epoch 25/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - val_loss: 0.2459
# Epoch 26/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0093 - val_loss: 0.5259
# Epoch 27/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - val_loss: 0.5510
# Epoch 28/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0097 - val_loss: 0.6440
# Epoch 29/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0095 - val_loss: 0.7202
# Epoch 30/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0094 - val_loss: 0.5862

# %%
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# Get predictions on scaled data
y_train_pred_scaled = model_dense.predict(X_train_scaled_2d)[:,0].reshape(-1, 1)
y_test_pred_scaled  = model_dense.predict(X_test_scaled_2d)[:,0].reshape(-1, 1)

# Inverse transform predictions to original scale
y_train_pred = scaler_y.inverse_transform(y_train_pred_scaled).flatten()
y_test_pred  = scaler_y.inverse_transform(y_test_pred_scaled).flatten()

# Define true unscaled values for comparison
y_train_true = y_train
y_test_true = y_test

# Create a figure with two subplots side by side
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Left subplot: Training and Validation Loss
ax.plot(history_dense.history['loss'], label='Training Loss')
ax.plot(history_dense.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()

r2_train = r2_score(y_train_true, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test_true, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train_true, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test_true, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

y_train_pred = pd.Series(y_train_pred, index=dates_train)
y_test_pred  = pd.Series(y_test_pred, index=dates_test)

# Calculate global y-axis limits
y_min = min(y_train_true.min(), y_train_pred.min(), y_test_true.min(), y_test_pred.min())
y_max = max(y_train_true.max(), y_train_pred.max(), y_test_true.max(), y_test_pred.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train, y_train_true, 'r', label='True')
axs[0].plot(y_train_pred, 'g', label='Predicted')
axs[0].set_title('Train Set')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test, y_test_true, 'r', label='True')
axs[1].plot(y_test_pred, 'g', label='Predicted')
axs[1].set_title('Test Set')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train_true, y_train_pred.values, 'c.')
axs[0].set_title('Train Set')
# axs[0].legend() # Removed as there's no label for scatter plot

axs[1].plot(y_test_true, y_test_pred.values, 'c.')
axs[1].set_title('Test Set')
# axs[1].legend() # Removed as there's no label for scatter plot

plt.tight_layout()
plt.show()

mae_train = mean_absolute_error(y_train_true, y_train_pred)
r2_train = r2_score(y_train_true, y_train_pred)
mae_test = mean_absolute_error(y_test_true, y_test_pred)
r2_test = r2_score(y_test_true, y_test_pred)

print("MAE:")
print(f"  Train: {mae_train:.4f}")
print(f"  Test:  {mae_test:.4f}")
print("R^2:")
print(f"  Train: {r2_train:.4f}")
print(f"  Test:  {r2_test:.4f}")
# Out:
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step
# r2_train:   0.98592
# r2_test:    0.99456
# rmse_train: 0.89439
# rmse_test:  5.355
# MAE:
#   Train: 0.4749
#   Test:  3.7647
# R^2:
#   Train: 0.9859
#   Test:  0.9946

# %%
#!mlflow ui
# Out:
# /bin/bash: line 1: mlflow: command not found

# %% [markdown]
# ### Alternative: Viewing MLflow UI with `localtunnel`
#
# Since `ngrok` requires an authenticated token, we can use `localtunnel` as an alternative. `localtunnel` can also expose your local MLflow UI to a public URL, often without requiring explicit authentication for basic use.

# %% [markdown]
# # LSTM

# %%
# Create lagged sequences
window_size = 10

#perm = np.arange(window_size)
perm = np.random.permutation(np.arange(window_size))

X_recent, y_recent = [], []
dates_recent = []
for i in range(len(stocks) - window_size):
    X_recent.append(stocks.iloc[i:i+window_size].values)
    # Predict only the 'close' price (index 1) for y
    y_recent.append(stocks.iloc[i+window_size, 1])
    dates_recent.append(stocks.index[i+window_size])

X_recent = np.array(X_recent)
y_recent = np.array(y_recent)
dates_recent = np.array(dates_recent)

print(f"X shape: {X_recent.shape}, y shape: {y_recent.shape}")
# Out:
# X shape: (11347, 10, 7), y shape: (11347,)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau # new update

# define training parameters
epochs          = 500
batch_size      = 256
decay_epochs    = int( epochs * 0.5 )

n_train         = X_train_3d.shape[0]
steps_per_epoch = int( np.ceil( n_train / batch_size ) )
decay_steps     = decay_epochs * steps_per_epoch
#print(decay_steps)

# Define the learning rate schedule
initial_learning_rate = 0.05

lr_schedule_exp = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_rate=5.0,
    decay_steps=decay_steps
)

lr_schedule_poly = PolynomialDecay(
    initial_learning_rate=initial_learning_rate,
    end_learning_rate=0.001,
    decay_steps=decay_steps,
    power=1.0
)

# Define the optimizer with a custom learning rate
optimizer = Adam(
    learning_rate=initial_learning_rate,
    #learning_rate=lr_schedule_exp,
    #learning_rate=lr_schedule_poly,
    #clipnorm=1,
    #clipvalue=1,
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=50,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# Callback to reduce LR when a monitored metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',       # metric to monitor
    factor=0.5,               # factor by which to reduce the LR
    patience=50,              # number of epochs with no improvement after which LR will be reduced
    min_lr=1e-6,              # lower bound on the learning rate
    verbose=1                 # print when LR is reduced
)

# Compile model
model.compile(
    optimizer=optimizer,
    loss='mae'
)

# %%
'''from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=50,          # Stop after 5 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

# Callback to reduce LR when a monitored metric has stopped improving
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',       # metric to monitor
    factor=0.5,               # factor by which to reduce the LR
    patience=50,              # number of epochs with no improvement after which LR will be reduced
    min_lr=1e-6,              # lower bound on the learning rate
    verbose=1                 # print when LR is reduced
)'''
# Out:
# "from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau\n\n# Early stopping callback\nearly_stopping = EarlyStopping(\n    monitor='val_loss',  # Monitor validation loss\n    patience=50,          # Stop after 5 epochs without improvement\n    restore_best_weights=True  # Restore the best weights after stopping\n)\n\n# Callback to reduce LR when a monitored metric has stopped improving\nreduce_lr = ReduceLROnPlateau(\n    monitor='val_loss',       # metric to monitor\n    factor=0.5,               # factor by which to reduce the LR\n    patience=50,              # number of epochs with no improvement after which LR will be reduced\n    min_lr=1e-6,              # lower bound on the learning rate\n    verbose=1                 # print when LR is reduced\n)"

# %% [markdown]
# ### Cross validation for LSTM entire stock dataset with scaling

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np

# Define the LSTM model building function for cross-validation
def build_lstm_model_cv(window_size, num_features, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential([
        Input(shape=(window_size, num_features)),
        LSTM(64, return_sequences=True),
        Dropout(dropout_rate),
        BatchNormalization(),
        LSTM(32, return_sequences=False),
        Dropout(dropout_rate),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mae')
    return model

# Assuming X_recent and y_recent are already defined and represent the data to be used
# X_recent has shape (n_samples, window_size, n_features)
# y_recent has shape (n_samples,)

# Define cross-validation parameters
n_splits = 5
kf_time_series = TimeSeriesSplit(n_splits=n_splits)

epochs = 150 # adjust this
batch_size = 64 # adjust this

train_mae_cv_list = []
test_mae_cv_list = []
train_r2_cv_list = []
test_r2_cv_list = []

fold = 1
# X_recent and y_recent are 3D and 1D respectively, but TimeSeriesSplit expects 2D array for X
# We will use X_recent_2d and reshape within the loop for LSTM input

# First, reshape X_recent to 2D for TimeSeriesSplit
X_recent_2d = X_recent.reshape(X_recent.shape[0], -1)

for train_index, test_index in kf_time_series.split(X_recent_2d):
    print(f"Fold {fold}/{n_splits}")

    # Split data for the current fold
    X_train_fold_2d, X_test_fold_2d = X_recent_2d[train_index], X_recent_2d[test_index]
    y_train_fold, y_test_fold = y_recent[train_index], y_recent[test_index]

    # Scale X and y within the fold to prevent data leakage
    scaler_X_cv = MinMaxScaler(feature_range=(0, 1))
    scaler_y_cv = MinMaxScaler(feature_range=(0, 1))

    X_train_scaled_2d = scaler_X_cv.fit_transform(X_train_fold_2d)
    X_test_scaled_2d = scaler_X_cv.transform(X_test_fold_2d)

    y_train_scaled = scaler_y_cv.fit_transform(y_train_fold.reshape(-1, 1))
    y_test_scaled = scaler_y_cv.transform(y_test_fold.reshape(-1, 1))

    # Reshape scaled X data to 3D for LSTM input
    current_window_size = X_recent.shape[1] # This should be 10
    current_num_features = X_recent.shape[2] # This should be 5

    X_train_scaled_3d_cv = X_train_scaled_2d.reshape((X_train_scaled_2d.shape[0], current_window_size, current_num_features))
    X_test_scaled_3d_cv = X_test_scaled_2d.reshape((X_test_scaled_2d.shape[0], current_window_size, current_num_features))

    # Build a fresh LSTM model for each fold
    model_lstm_cv = build_lstm_model_cv(current_window_size, current_num_features)

    # Early stopping callback
    early_stopping_cv = EarlyStopping(
        monitor='val_loss',
        patience=25, # Adjusted patience for cross-validation
        restore_best_weights=True
    )

    # Train the model
    history_cv = model_lstm_cv.fit(
        X_train_scaled_3d_cv, y_train_scaled,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_scaled_3d_cv, y_test_scaled),
        verbose=0,
        callbacks=[early_stopping_cv]
    )

    # Evaluate on training data
    y_train_pred_scaled_cv = model_lstm_cv.predict(X_train_scaled_3d_cv, verbose=0)
    y_train_pred_cv = scaler_y_cv.inverse_transform(y_train_pred_scaled_cv) # Inverse transform predictions
    train_mae_cv = mean_absolute_error(y_train_fold, y_train_pred_cv)
    train_r2_cv = r2_score(y_train_fold, y_train_pred_cv)

    # Evaluate on test data
    y_test_pred_scaled_cv = model_lstm_cv.predict(X_test_scaled_3d_cv, verbose=0)
    y_test_pred_cv = scaler_y_cv.inverse_transform(y_test_pred_scaled_cv) # Inverse transform predictions
    test_mae_cv = mean_absolute_error(y_test_fold, y_test_pred_cv)
    test_r2_cv = r2_score(y_test_fold, y_test_pred_cv)

    print("MAE:")
    print(f"  Train: {train_mae_cv:.4f}")
    print(f"  Test:  {test_mae_cv:.4f}")
    print("R^2:")
    print(f"  Train: {train_r2_cv:.4f}")
    print(f"  Test:  {test_r2_cv:.4f}")
    print()

    train_mae_cv_list.append(train_mae_cv)
    test_mae_cv_list.append(test_mae_cv)
    train_r2_cv_list.append(train_r2_cv)
    test_r2_cv_list.append(test_r2_cv)

    fold += 1
# end

print("\nCross-validation results:")
cv_results_df = pd.DataFrame({
    'Train MAE': train_mae_cv_list,
    'Test MAE': test_mae_cv_list,
    'Train R2': train_r2_cv_list,
    'Test R2': test_r2_cv_list
})
display(cv_results_df)
display(cv_results_df.describe())
# Out:
# Fold 1/5
# MAE:
#   Train: 0.0054
#   Test:  0.0102
# R^2:
#   Train: 0.9925
#   Test:  0.9608
#
# Fold 2/5
# MAE:
#   Train: 0.0167
#   Test:  0.0300
# R^2:
#   Train: 0.9675
#   Test:  0.8706
#
# Fold 3/5
# MAE:
#   Train: 0.0296
#   Test:  2.6207
# R^2:
#   Train: 0.9475
#   Test:  -0.9402
#
# Fold 4/5
# MAE:
#   Train: 0.3302
#   Test:  10.3378
# R^2:
#   Train: 0.8789
#   Test:  -0.8954
#
# Fold 5/5
# MAE:
#   Train: 0.6038
#   Test:  89.2282
# R^2:
#   Train: 0.9860
#   Test:  -1.7008
#
#
# Cross-validation results:
#    Train MAE   Test MAE  Train R2   Test R2
# 0   0.005390   0.010163  0.992508  0.960839
# 1   0.016705   0.029962  0.967548  0.870575
# 2   0.029634   2.620727  0.947517 -0.940161
# 3   0.330170  10.337758  0.878926 -0.895365
# 4   0.603797  89.228173  0.985972 -1.700835
#        Train MAE   Test MAE  Train R2   Test R2
# count   5.000000   5.000000  5.000000  5.000000
# mean    0.197139  20.445356  0.954494 -0.340989
# std     0.264788  38.682497  0.045732  1.191445
# min     0.005390   0.010163  0.878926 -1.700835
# 25%     0.016705   0.029962  0.947517 -0.940161
# 50%     0.029634   2.620727  0.967548 -0.895365
# 75%     0.330170  10.337758  0.985972  0.870575
# max     0.603797  89.228173  0.992508  0.960839

# %%
num_features = X_train_3d.shape[2]

model_lstm = Sequential([
    Input(shape=(window_size, num_features)),

    LSTM(64, return_sequences=True),
    Dropout(0.2),
    BatchNormalization(),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(32, activation='relu'),
    Dense(1)
])

# Define the optimizer with a custom learning rate
optimizer = Adam(learning_rate=0.001)

# Compile model
model_lstm.compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 25 epochs without improvement
    restore_best_weights=True  # Restore the best weights after stopping
)

model_lstm.summary()

# Re-scale y_train and y_test using the original scaler_y from the initial split
y_train_scaled = scaler_y.transform(y_train.reshape(-1,1))
y_test_scaled  = scaler_y.transform(y_test.reshape(-1,1))

# Train the LSTM model with the correctly scaled data from the initial 80/20 split
history_lstm = model_lstm.fit(
    X_train_scaled_3d, y_train_scaled,
    epochs=150,
    batch_size=64,
    validation_data=(X_test_scaled_3d, y_test_scaled),
    verbose=1,
    callbacks=[early_stopping]
)
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 10, 64)         │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 10, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,193 (125.75 KB)
#  Trainable params: 32,065 (125.25 KB)
#  Non-trainable params: 128 (512.00 B)
# Epoch 1/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 0.0405 - val_loss: 2.0504
# Epoch 2/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0172 - val_loss: 1.8775
# Epoch 3/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0130 - val_loss: 1.8767
# Epoch 4/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0106 - val_loss: 1.8288
# Epoch 5/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0099 - val_loss: 1.7783
# Epoch 6/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0092 - val_loss: 1.8335
# Epoch 7/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0088 - val_loss: 1.8279
# Epoch 8/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0083 - val_loss: 1.7832
# Epoch 9/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0083 - val_loss: 1.6568
# Epoch 10/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0083 - val_loss: 1.7685
# Epoch 11/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0074 - val_loss: 1.6268
# Epoch 12/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - val_loss: 1.6283
# Epoch 13/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0068 - val_loss: 1.6773
# Epoch 14/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0066 - val_loss: 1.6447
# Epoch 15/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - val_loss: 1.4847
# Epoch 16/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0062 - val_loss: 1.4690
# Epoch 17/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - val_loss: 1.6589
# Epoch 18/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0059 - val_loss: 1.5281
# Epoch 19/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0056 - val_loss: 1.4109
# Epoch 20/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0056 - val_loss: 1.3340
# Epoch 21/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0055 - val_loss: 1.4412
# Epoch 22/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - val_loss: 1.4978
# Epoch 23/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0053 - val_loss: 1.4047
# Epoch 24/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 1.5310
# Epoch 25/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0049 - val_loss: 1.3354
# Epoch 26/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - val_loss: 1.2787
# Epoch 27/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - val_loss: 1.1711
# Epoch 28/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0047 - val_loss: 1.2504
# Epoch 29/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - val_loss: 1.1994
# Epoch 30/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - val_loss: 1.1083
# Epoch 31/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0045 - val_loss: 1.3258
# Epoch 32/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0044 - val_loss: 1.2010
# Epoch 33/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0042 - val_loss: 1.0706
# Epoch 34/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - val_loss: 1.2192
# Epoch 35/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0040 - val_loss: 1.5005
# Epoch 36/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 1.1196
# Epoch 37/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0041 - val_loss: 1.4572
# Epoch 38/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0039 - val_loss: 1.5060
# Epoch 39/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 1.6415
# Epoch 40/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - val_loss: 1.5822
# Epoch 41/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - val_loss: 1.5276
# Epoch 42/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - val_loss: 1.0461
# Epoch 43/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 1.3862
# Epoch 44/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 1.1253
# Epoch 45/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 1.1930
# Epoch 46/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0036 - val_loss: 1.2529
# Epoch 47/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0037 - val_loss: 1.1187
# Epoch 48/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 1.1252
# Epoch 49/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 1.3633
# Epoch 50/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 1.6658
# Epoch 51/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0035 - val_loss: 1.5404
# Epoch 52/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 1.4612
# Epoch 53/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 1.3317
# Epoch 54/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 1.5870
# Epoch 55/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0032 - val_loss: 1.5840
# Epoch 56/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 1.5912
# Epoch 57/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 1.7167
# Epoch 58/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 1.6797
# Epoch 59/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 1.4714
# Epoch 60/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0033 - val_loss: 1.5165
# Epoch 61/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0034 - val_loss: 1.4697
# Epoch 62/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0031 - val_loss: 1.4591
# Epoch 63/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0029 - val_loss: 1.4641
# Epoch 64/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 1.2769
# Epoch 65/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0032 - val_loss: 1.3173
# Epoch 66/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 1.5209
# Epoch 67/150
# 142/142 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0030 - val_loss: 1.4671

# %%
'''history_lstm = model_lstm.fit(
    X_train_scaled_3d, y_train_scaled, # Use scaled 3D data
    epochs=150,
    batch_size=64,
    validation_data=(X_test_scaled_3d, y_test_scaled), # Use scaled 3D data for validation
    verbose=1,
    callbacks=[early_stopping]
)'''
# Out:
# 'history_lstm = model_lstm.fit(\n    X_train_scaled_3d, y_train_scaled, # Use scaled 3D data\n    epochs=150,\n    batch_size=64,\n    validation_data=(X_test_scaled_3d, y_test_scaled), # Use scaled 3D data for validation\n    verbose=1,\n    callbacks=[early_stopping]\n)'

# %%
# Get predictions on scaled data
y_train_pred_scaled = model_lstm.predict(X_train_scaled_3d)[:,0].reshape(-1, 1)
y_test_pred_scaled  = model_lstm.predict(X_test_scaled_3d)[:,0].reshape(-1, 1)

# Inverse transform predictions to original scale
y_train_pred = scaler_y.inverse_transform(y_train_pred_scaled).flatten()
y_test_pred  = scaler_y.inverse_transform(y_test_pred_scaled).flatten()

# Now use the true values and dates from the train_test_split
y_train_true = y_train
y_test_true = y_test
dates_train_plot = dates_train
dates_test_plot = dates_test

# Create a figure with one subplot for loss
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Plot Training and Validation Loss
ax.plot(history_lstm.history['loss'], label='Training Loss')
ax.plot(history_lstm.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss (LSTM)')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
plt.tight_layout()
plt.show()

# Calculate metrics for LSTM model
r2_train = r2_score(y_train_true, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test_true, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train_true, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test_true, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

# Convert predictions to pandas Series with dates as index for plotting
y_train_pred_series = pd.Series(y_train_pred.flatten(), index=dates_train_plot)
y_test_pred_series  = pd.Series(y_test_pred.flatten(), index=dates_test_plot)

# Calculate global y-axis limits for consistent plotting
y_min = min(y_train_true.min(), y_train_pred_series.min(), y_test_true.min(), y_test_pred_series.min())
y_max = max(y_train_true.max(), y_train_pred_series.max(), y_test_true.max(), y_test_pred_series.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train_plot, y_train_true, 'r', label='True')
axs[0].plot(y_train_pred_series, 'g', label='Predicted')
axs[0].set_title('Train Set (LSTM)')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test_plot, y_test_true, 'r', label='True')
axs[1].plot(y_test_pred_series, 'g', label='Predicted')
axs[1].set_title('Test Set (LSTM)')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot scatter plots for train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train_true, y_train_pred_series.values, 'c.')
axs[0].set_title('Train Set (LSTM)')
axs[0].set_xlabel('True Values')
axs[0].set_ylabel('Predicted Values')
# axs[0].legend() # Removed as there's no label for scatter plot

axs[1].plot(y_test_true, y_test_pred_series.values, 'c.')
axs[1].set_title('Test Set (LSTM)')
axs[1].set_xlabel('True Values')
axs[1].set_ylabel('Predicted Values')
# axs[1].legend() # Removed as there's no label for scatter plot

plt.tight_layout()
plt.show()

mae_train = mean_absolute_error(y_train_true, y_train_pred)
mae_test = mean_absolute_error(y_test_true, y_test_pred)

print("MAE:")
print(f"  Train: {mae_train:.4f}")
print(f"  Test:  {mae_test:.4f}")
print("R^2:")
print(f"  Train: {r2_train:.4f}")
print(f"  Test:  {r2_test:.4f}")
# Out:
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# r2_train:   0.98202
# r2_test:    -0.13124
# rmse_train: 1.0107
# rmse_test:  77.232
# MAE:
#   Train: 0.4173
#   Test:  56.8205
# R^2:
#   Train: 0.9820
#   Test:  -0.1312

# %% [markdown]
# the negative R² scores is a direct consequence of the model struggling with the non-stationary nature of stock prices over the extreme range present in the dataset (1980 to 2026).

# %% [markdown]
# #Gemini Suggestion and my fix

# %% [markdown]
# ### Scaling Data for LSTM Training
#
# The previous LSTM model was trained on unscaled data. It's crucial for neural networks like LSTMs to train on scaled data for better convergence and performance. We will now apply `MinMaxScaler` to the training and testing sets of `X` and `y` that were derived from the feature-selected data (`X_pars`).
#
# The `scaler_X_final` will be fitted on the 2D `X_train` (before reshaping to 3D for LSTM) and `scaler_y_final` will be fitted on `y_train`. These scalers will then be used to transform both the training and testing sets.

# %% [markdown]
# *********************************************
# ### If it doesnt work run lstm in new notebook
# *********************************************

# %% [markdown]
# Suggest to use a rolling wondow training to predict stock based on a 6 month window (windowssize = 10 days) .tail(180) or window size = 180. Train on the window and predict the next day.week. Retrain to incorporatee new actual data point.
#
# For cross validation, fold with high R square correlates with stationarity mwanwhilee financial market are non stationary, low volatility, less noise. If i select aa performance in low volatility stationary period I am essentially training a fair weather nnodel that perform well when the mareet is quiet. Use multiple fold or regime detection to determine if current market is currently sationary or regime-shifting.
#
# Use streess testing (isolate folds with low R square) and use as stress test set. If model can be improved to maintaainn even modest R square during ow volatilituy folds it will be significantly more robust than a modl that use only high R scores

# %%
# Install TensorBoard if not already installed
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (1.81.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/lib/python3/dist-packages (from tensorboard) (3.3.6)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (2.4.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorboard) (26.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard) (12.2.0)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (6.33.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (75.2.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard) (3.1.8)
# Requirement already satisfied: typing-extensions~=4.12 in /usr/local/lib/python3.12/dist-packages (from grpcio>=1.48.2->tensorboard) (4.15.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard) (3.0.3)
# Downloading tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 110.5 MB/s eta 0:00:00
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 204.9 MB/s eta 0:00:00
# Installing collected packages: tensorboard-data-server, tensorboard
# Successfully installed tensorboard-2.20.0 tensorboard-data-server-0.7.2

# %%
recent_stocks = stocks.tail(574)
recent_stocks
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2023-12-01  188.373065  189.590414  187.284369  189.273712  45704800
# 2023-12-04  188.026663  188.095951  185.522677  187.482315  43389500
# 2023-12-05  188.254333  192.401240  188.224627  191.431320  66628400
# 2023-12-06  192.450710  192.757521  190.134773  190.342621  41089700
# 2023-12-07  191.639164  192.995073  191.599567  192.272583  47477700
# ...                ...         ...         ...         ...       ...
# 2026-03-12  258.660004  258.950012  254.179993  255.759995  40794000
# 2026-03-13  255.479996  256.329987  249.520004  250.119995  36930000
# 2026-03-16  252.110001  253.889999  249.880005  252.820007  32074200
# 2026-03-17  252.960007  255.130005  252.179993  254.229996  32361600
# 2026-03-18  252.625000  254.940002  249.000000  249.940002  34652568
#
#             Moving_Average        RSI
# Date
# 2023-12-01      177.446822  67.053646
# 2023-12-04      177.741163  61.115171
# 2023-12-05      178.088983  67.841875
# 2023-12-06      178.496475  64.543803
# 2023-12-07      178.972812  67.540913
# ...                    ...        ...
# 2026-03-12      263.034650  40.400334
# 2026-03-13      262.580556  35.468931
# 2026-03-16      262.204839  39.271095
# 2026-03-17      261.874306  41.209231
# 2026-03-18      261.532903  37.325909
#
# [574 rows x 7 columns]

# %%
# Create lagged sequences
window_size = 10

#perm = np.arange(window_size)
perm = np.random.permutation(np.arange(window_size))

X_recent, y_recent = [], []
dates_recent = []
for i in range(len(recent_stocks) - window_size):
    X_recent.append(recent_stocks.iloc[i:i+window_size].values)
    # Predict only the 'close' price (index 1) for y
    y_recent.append(recent_stocks.iloc[i+window_size, 1])
    dates_recent.append(recent_stocks.index[i+window_size])

X_recent = np.array(X_recent)
y_recent = np.array(y_recent)
dates_recent = np.array(dates_recent)

print(f"X shape: {X_recent.shape}, y shape: {y_recent.shape}")
# Out:
# X shape: (564, 10, 7), y shape: (564,)

# %% [markdown]
# ### Time Series Cross-Validation for LSTM Model Scaled Data
#
# This provide a more robust evaluation of the model's performance across different time periods, similar to how other models were evaluated.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import numpy as np



# Define the LSTM model building function for cross-validation
def build_lstm_model_cv(window_size, num_features, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential([
        Input(shape=(window_size, num_features)),
        LSTM(64, return_sequences=True),
        Dropout(dropout_rate),
        BatchNormalization(),
        LSTM(32, return_sequences=False),
        Dropout(dropout_rate),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mae')
    return model

# Assuming X_recent and y_recent are already defined and represent the data to be used
# X_recent has shape (n_samples, window_size, n_features)
# y_recent has shape (n_samples,)

# Define cross-validation parameters
n_splits = 5
kf_time_series = TimeSeriesSplit(n_splits=n_splits)

epochs = 150 # adjust this
batch_size = 64 # adjust this

train_mae_cv_list = []
test_mae_cv_list = []
train_r2_cv_list = []
test_r2_cv_list = []

fold = 1
# X_recent and y_recent are 3D and 1D respectively, but TimeSeriesSplit expects 2D array for X
# We will use X_recent_2d and reshape within the loop for LSTM input

# First, reshape X_recent to 2D for TimeSeriesSplit
X_recent_2d = X_recent.reshape(X_recent.shape[0], -1)

for train_index, test_index in kf_time_series.split(X_recent_2d):
    print(f"Fold {fold}/{n_splits}")

    # Split data for the current fold
    X_train_fold_2d, X_test_fold_2d = X_recent_2d[train_index], X_recent_2d[test_index]
    y_train_fold, y_test_fold = y_recent[train_index], y_recent[test_index]

    # Scale X and y within the fold to prevent data leakage
    scaler_X_cv = MinMaxScaler(feature_range=(0, 1))
    scaler_y_cv = MinMaxScaler(feature_range=(0, 1))

    X_train_scaled_2d = scaler_X_cv.fit_transform(X_train_fold_2d)
    X_test_scaled_2d = scaler_X_cv.transform(X_test_fold_2d)

    y_train_scaled = scaler_y_cv.fit_transform(y_train_fold.reshape(-1, 1))
    y_test_scaled = scaler_y_cv.transform(y_test_fold.reshape(-1, 1))

    # Reshape scaled X data to 3D for LSTM input
    current_window_size = X_recent.shape[1] # This should be 10
    current_num_features = X_recent.shape[2] # This should be 5

    X_train_scaled_3d_cv = X_train_scaled_2d.reshape((X_train_scaled_2d.shape[0], current_window_size, current_num_features))
    X_test_scaled_3d_cv = X_test_scaled_2d.reshape((X_test_scaled_2d.shape[0], current_window_size, current_num_features))

    # Build a fresh LSTM model for each fold
    model_lstm_cv = build_lstm_model_cv(current_window_size, current_num_features)

    # Early stopping callback
    early_stopping_cv = EarlyStopping(
        monitor='val_loss',
        patience=25, # Adjusted patience for cross-validation
        restore_best_weights=True
    )

    # Train the model
    history_cv = model_lstm_cv.fit(
        X_train_scaled_3d_cv, y_train_scaled,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_scaled_3d_cv, y_test_scaled),
        verbose=0,
        callbacks=[early_stopping_cv]
    )

    # Evaluate on training data
    y_train_pred_scaled_cv = model_lstm_cv.predict(X_train_scaled_3d_cv, verbose=0)
    y_train_pred_cv = scaler_y_cv.inverse_transform(y_train_pred_scaled_cv) # Inverse transform predictions
    train_mae_cv = mean_absolute_error(y_train_fold, y_train_pred_cv)
    train_r2_cv = r2_score(y_train_fold, y_train_pred_cv)

    # Evaluate on test data
    y_test_pred_scaled_cv = model_lstm_cv.predict(X_test_scaled_3d_cv, verbose=0)
    y_test_pred_cv = scaler_y_cv.inverse_transform(y_test_pred_scaled_cv) # Inverse transform predictions
    test_mae_cv = mean_absolute_error(y_test_fold, y_test_pred_cv)
    test_r2_cv = r2_score(y_test_fold, y_test_pred_cv)

    print("MAE:")
    print(f"  Train: {train_mae_cv:.4f}")
    print(f"  Test:  {test_mae_cv:.4f}")
    print("R^2:")
    print(f"  Train: {train_r2_cv:.4f}")
    print(f"  Test:  {test_r2_cv:.4f}")
    print()

    train_mae_cv_list.append(train_mae_cv)
    test_mae_cv_list.append(test_mae_cv)
    train_r2_cv_list.append(train_r2_cv)
    test_r2_cv_list.append(test_r2_cv)

    fold += 1
# end

print("\nCross-validation results:")
cv_results_df = pd.DataFrame({
    'Train MAE': train_mae_cv_list,
    'Test MAE': test_mae_cv_list,
    'Train R2': train_r2_cv_list,
    'Test R2': test_r2_cv_list
})
display(cv_results_df)
display(cv_results_df.describe())
# Out:
# 2026/06/21 08:16:03 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '3fcce365962c48caba2c61b2a63629e4', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# Fold 1/5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# WARNING:tensorflow:5 out of the last 1391 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x798698571bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 2026/06/21 08:16:17 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run blushing-asp-708 at: http://localhost:5000/#/experiments/1/runs/3fcce365962c48caba2c61b2a63629e4
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/06/21 08:16:22 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '276efc70ee8b493894c473b29d99775d', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# MAE:
#   Train: 2.8511
#   Test:  22.4954
# R^2:
#   Train: 0.8345
#   Test:  -1.4870
#
# Fold 2/5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 2026/06/21 08:16:38 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# WARNING:tensorflow:5 out of the last 28 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x798774ab65c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 🏃 View run nebulous-boar-581 at: http://localhost:5000/#/experiments/1/runs/276efc70ee8b493894c473b29d99775d
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/06/21 08:16:43 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '7484a6d0baa64388ad06e4c929ed1d40', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# MAE:
#   Train: 5.4286
#   Test:  12.6513
# R^2:
#   Train: 0.8893
#   Test:  -1.3006
#
# Fold 3/5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2026/06/21 08:16:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run mysterious-hog-435 at: http://localhost:5000/#/experiments/1/runs/7484a6d0baa64388ad06e4c929ed1d40
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/06/21 08:17:02 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'f75edc28b3d4442aaca0a7e88735d7b9', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# MAE:
#   Train: 7.1037
#   Test:  7.5498
# R^2:
#   Train: 0.8715
#   Test:  0.6609
#
# Fold 4/5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 2026/06/21 08:17:21 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run legendary-bear-874 at: http://localhost:5000/#/experiments/1/runs/f75edc28b3d4442aaca0a7e88735d7b9
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 2026/06/21 08:17:26 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'dd467d19d8804b918380b27c68c2b983', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# MAE:
#   Train: 3.0316
#   Test:  4.9671
# R^2:
#   Train: 0.9725
#   Test:  0.9082
#
# Fold 5/5
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 2026/06/21 08:17:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run adventurous-bear-659 at: http://localhost:5000/#/experiments/1/runs/dd467d19d8804b918380b27c68c2b983
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# MAE:
#   Train: 3.2730
#   Test:  4.4714
# R^2:
#   Train: 0.9681
#   Test:  0.6394
#
#
# Cross-validation results:
#    Train MAE   Test MAE  Train R2   Test R2
# 0   2.851079  22.495350  0.834483 -1.487021
# 1   5.428622  12.651299  0.889270 -1.300554
# 2   7.103704   7.549808  0.871468  0.660945
# 3   3.031628   4.967051  0.972511  0.908185
# 4   3.273034   4.471357  0.968128  0.639414
#        Train MAE   Test MAE  Train R2   Test R2
# count   5.000000   5.000000  5.000000  5.000000
# mean    4.337613  10.426973  0.907172 -0.115806
# std     1.863482   7.485846  0.060959  1.173256
# min     2.851079   4.471357  0.834483 -1.487021
# 25%     3.031628   4.967051  0.871468 -1.300554
# 50%     3.273034   7.549808  0.889270  0.639414
# 75%     5.428622  12.651299  0.968128  0.660945
# max     7.103704  22.495350  0.972511  0.908185

# %% [markdown]
# ### Defining training parameter

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.schedules import ExponentialDecay, PolynomialDecay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input

# define training parameters
epochs          = 250
batch_size      = 256
decay_epochs    = int( epochs * 0.5 )

n_train         = X_train_3d.shape[0]
steps_per_epoch = int( np.ceil( n_train / batch_size ) )
decay_steps     = decay_epochs * steps_per_epoch
#print(decay_steps)

# Define the learning rate schedule
initial_learning_rate = 0.001 # Changed from 0.05 to 0.001 to match CV setup

lr_schedule_exp = ExponentialDecay(
    initial_learning_rate=initial_learning_rate,
    decay_rate=5.0,
    decay_steps=decay_steps
)

lr_schedule_poly = PolynomialDecay(
    initial_learning_rate=initial_learning_rate,
    end_learning_rate=0.001,
    decay_steps=decay_steps,
    power=1.0
)

# Define model_lstm_final (moved from a later cell)
window_size = 10 # Assuming this is consistent
num_features = X_train_3d.shape[2] # Corrected: Derive num_features from the actual number of features

model_lstm_final = Sequential([
    Input(shape=(window_size, num_features)),
    LSTM(64, return_sequences=True),
    Dropout(0.2),
    BatchNormalization(),
    LSTM(32, return_sequences=False),
    Dropout(0.2),
    Dense(32, activation='relu'),
    Dense(1)
])

# Define the optimizer with a custom learning rate
optimizer = Adam(
    learning_rate=initial_learning_rate,
    #learning_rate=lr_schedule_exp,
    #learning_rate=lr_schedule_poly,
    #clipnorm=1,
    #clipvalue=1,
)

# Compile model
model_lstm_final.compile(
    optimizer=optimizer,
    loss='mae'
)

# %% [markdown]
# ### Retraining LSTM Model with Scaled Data
#
# Now we will define and retrain the LSTM model using the newly scaled `X_train_scaled_3d` and `y_train_scaled` data. We will use the same architecture and early stopping mechanism as before. After training, we will evaluate its performance.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler # Import MinMaxScaler

# Correctly determine the number of features from the scaled 3D data
num_features = X_train_scaled_3d_cv.shape[2]

# Define the LSTM model with the same architecture as before
model_lstm_final = Sequential([
    Input(shape=(window_size, num_features)), # Use the correctly calculated num_features

    LSTM(64, return_sequences=True),
    Dropout(0.2),
    BatchNormalization(),

    LSTM(32, return_sequences=False),
    Dropout(0.2),

    Dense(32, activation='relu'),
    Dense(1)
])

# Define the optimizer and compile the model
optimizer = Adam(learning_rate=0.001) # Use the same learning rate as previous LSTM
model_lstm_final.compile(
    optimizer=optimizer,
    loss='mae',
)

# Early stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    patience=25,          # Stop after 25 epochs without improvement (consistent with previous)
    restore_best_weights=True  # Restore the best weights after stopping
)

model_lstm_final.summary()

# --- Start of added check for data cardinality ---
#print(f"Checking X_train_scaled_3d shape: {X_train_scaled_3d_cv.shape}")
#print(f"Checking y_train_scaled shape: {y_train_scaled.shape}")

#if X_train_scaled_3d.shape[0] != y_train_scaled.shape[0]:
#    raise ValueError(f"Data cardinality mismatch: X_train has {X_train_scaled_3d.shape[0]} samples, but y_train has {y_train_scaled.shape[0]} samples.")
# --- End of added check for data cardinality ---

# Initialize and fit scaler_y_final with the unscaled y_train_fold from the last CV fold
scaler_y_final = MinMaxScaler(feature_range=(0, 1))
scaler_y_final.fit(y_train_fold.reshape(-1, 1))

# Train the model with scaled data
history_lstm_final = model_lstm_final.fit(
    X_train_scaled_3d_cv, y_train_scaled,
    epochs=250, # Use same number of epochs
    batch_size=64, # Reverting batch size as per user's preference
    validation_data=(X_test_scaled_3d_cv, y_test_scaled),
    verbose=1,
    callbacks=[early_stopping]
)

# Get predictions using the final model
y_train_pred_scaled = model_lstm_final.predict(X_train_scaled_3d_cv)
y_test_pred_scaled  = model_lstm_final.predict(X_test_scaled_3d_cv)

# Inverse transform predictions to original scale
y_train_pred = scaler_y_final.inverse_transform(y_train_pred_scaled)
y_test_pred  = scaler_y_final.inverse_transform(y_test_pred_scaled)

# Inverse transform true values for consistent comparison based on the cv fold
y_train_true_original = y_train_fold
y_test_true_original = y_test_fold

# Calculate metrics for the retrained LSTM model
r2_train = r2_score(y_train_true_original, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test_true_original, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train_true_original, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test_true_original, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')
# Out:
# Model: "sequential_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_44 (LSTM)                  │ (None, 10, 64)         │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_56 (Dropout)            │ (None, 10, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 10, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_45 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_57 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_68 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_69 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 32,193 (125.75 KB)
#  Trainable params: 32,065 (125.25 KB)
#  Non-trainable params: 128 (512.00 B)
# 2026/06/21 08:18:50 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '2b044b12f2dd4051ad0e1e2ab00370f5', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2459
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 0.2128 - val_loss: 0.6528
# Epoch 2/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1445 - val_loss: 0.6945
# Epoch 3/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1366
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1344 - val_loss: 0.6003
# Epoch 4/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1189 - val_loss: 0.6380
# Epoch 5/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1141
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1118 - val_loss: 0.5750
# Epoch 6/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1029 - val_loss: 0.6154
# Epoch 7/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0847
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0964 - val_loss: 0.5593
# Epoch 8/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0945 - val_loss: 0.5731
# Epoch 9/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0711
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0836 - val_loss: 0.5448
# Epoch 10/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0778 - val_loss: 0.5527
# Epoch 11/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0892 - val_loss: 0.5608
# Epoch 12/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0725
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0793 - val_loss: 0.5446
# Epoch 13/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0786
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0766 - val_loss: 0.5189
# Epoch 14/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0601
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0694 - val_loss: 0.4979
# Epoch 15/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0689
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0681 - val_loss: 0.4854
# Epoch 16/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0703
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0704 - val_loss: 0.4819
# Epoch 17/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0832
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0712 - val_loss: 0.4548
# Epoch 18/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0678 - val_loss: 0.4993
# Epoch 19/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0635
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0769 - val_loss: 0.4356
# Epoch 20/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0694 - val_loss: 0.5096
# Epoch 21/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0657 - val_loss: 0.4405
# Epoch 22/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0681 - val_loss: 0.4796
# Epoch 23/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0603
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0624 - val_loss: 0.4182
# Epoch 24/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0623 - val_loss: 0.4563
# Epoch 25/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0640 - val_loss: 0.4354
# Epoch 26/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0598 - val_loss: 0.4517
# Epoch 27/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0614 - val_loss: 0.4216
# Epoch 28/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0600 - val_loss: 0.4264
# Epoch 29/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0513
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0580 - val_loss: 0.4117
# Epoch 30/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0613
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0576 - val_loss: 0.4075
# Epoch 31/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0543 - val_loss: 0.4244
# Epoch 32/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0677
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0602 - val_loss: 0.3834
# Epoch 33/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0602 - val_loss: 0.4395
# Epoch 34/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0475
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0602 - val_loss: 0.3662
# Epoch 35/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0545 - val_loss: 0.3919
# Epoch 36/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0498
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0541 - val_loss: 0.3554
# Epoch 37/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0517 - val_loss: 0.3873
# Epoch 38/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0500
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0572 - val_loss: 0.3349
# Epoch 39/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0536 - val_loss: 0.3579
# Epoch 40/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0544 - val_loss: 0.3361
# Epoch 41/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0477 - val_loss: 0.3353
# Epoch 42/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0622
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0520 - val_loss: 0.3234
# Epoch 43/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0491 - val_loss: 0.3250
# Epoch 44/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0426
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0502 - val_loss: 0.2929
# Epoch 45/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0528 - val_loss: 0.2985
# Epoch 46/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0495
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0464 - val_loss: 0.2860
# Epoch 47/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0494
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0464 - val_loss: 0.2673
# Epoch 48/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0418
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0437 - val_loss: 0.2656
# Epoch 49/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0502 - val_loss: 0.2839
# Epoch 50/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0451
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0488 - val_loss: 0.2622
# Epoch 51/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0424
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0469 - val_loss: 0.2266
# Epoch 52/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0477 - val_loss: 0.2755
# Epoch 53/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0535
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0472 - val_loss: 0.1792
# Epoch 54/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0432 - val_loss: 0.2121
# Epoch 55/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0451 - val_loss: 0.2527
# Epoch 56/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0462 - val_loss: 0.2607
# Epoch 57/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0514 - val_loss: 0.2536
# Epoch 58/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0470 - val_loss: 0.1961
# Epoch 59/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0416 - val_loss: 0.2431
# Epoch 60/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0409
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0453 - val_loss: 0.1189
# Epoch 61/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0475 - val_loss: 0.1651
# Epoch 62/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0428 - val_loss: 0.2344
# Epoch 63/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0443 - val_loss: 0.2193
# Epoch 64/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0480 - val_loss: 0.1776
# Epoch 65/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0471 - val_loss: 0.3147
# Epoch 66/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0545 - val_loss: 0.1938
# Epoch 67/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0488 - val_loss: 0.2166
# Epoch 68/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0481 - val_loss: 0.1769
# Epoch 69/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0414 - val_loss: 0.1830
# Epoch 70/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0413 - val_loss: 0.1878
# Epoch 71/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0428 - val_loss: 0.1913
# Epoch 72/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0460 - val_loss: 0.2175
# Epoch 73/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0470 - val_loss: 0.1524
# Epoch 74/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0460
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0444 - val_loss: 0.0666
# Epoch 75/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0429 - val_loss: 0.2023
# Epoch 76/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0428 - val_loss: 0.1174
# Epoch 77/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0397 - val_loss: 0.1576
# Epoch 78/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0376 - val_loss: 0.1882
# Epoch 79/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0408 - val_loss: 0.1040
# Epoch 80/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0391 - val_loss: 0.0851
# Epoch 81/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0397 - val_loss: 0.1514
# Epoch 82/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0372 - val_loss: 0.2135
# Epoch 83/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0409 - val_loss: 0.0958
# Epoch 84/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0402 - val_loss: 0.2006
# Epoch 85/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0515
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0447 - val_loss: 0.0549
# Epoch 86/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0378 - val_loss: 0.1694
# Epoch 87/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0390 - val_loss: 0.0679
# Epoch 88/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0419 - val_loss: 0.1932
# Epoch 89/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0415 - val_loss: 0.1155
# Epoch 90/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0429 - val_loss: 0.2205
# Epoch 91/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0422 - val_loss: 0.0579
# Epoch 92/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0468 - val_loss: 0.2235
# Epoch 93/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0404 - val_loss: 0.1057
# Epoch 94/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0366 - val_loss: 0.1707
# Epoch 95/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0366 - val_loss: 0.1080
# Epoch 96/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0426 - val_loss: 0.1749
# Epoch 97/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0384 - val_loss: 0.0959
# Epoch 98/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0403 - val_loss: 0.1416
# Epoch 99/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0393 - val_loss: 0.0850
# Epoch 100/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0311
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0402 - val_loss: 0.0485
# Epoch 101/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0397 - val_loss: 0.0943
# Epoch 102/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0361 - val_loss: 0.0884
# Epoch 103/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0286
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0372 - val_loss: 0.0385
# Epoch 104/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0409 - val_loss: 0.1834
# Epoch 105/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0402 - val_loss: 0.0976
# Epoch 106/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0339 - val_loss: 0.0780
# Epoch 107/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0355 - val_loss: 0.0483
# Epoch 108/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0354 - val_loss: 0.0449
# Epoch 109/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0360 - val_loss: 0.0942
# Epoch 110/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0401 - val_loss: 0.0829
# Epoch 111/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0505
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0373 - val_loss: 0.0292
# Epoch 112/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0375 - val_loss: 0.0488
# Epoch 113/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0388 - val_loss: 0.0391
# Epoch 114/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0361 - val_loss: 0.1533
# Epoch 115/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0368 - val_loss: 0.1733
# Epoch 116/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0374 - val_loss: 0.1272
# Epoch 117/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0353 - val_loss: 0.1783
# Epoch 118/250
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0276
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0365 - val_loss: 0.0273
# Epoch 119/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0350 - val_loss: 0.1564
# Epoch 120/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0395 - val_loss: 0.1038
# Epoch 121/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0375 - val_loss: 0.1634
# Epoch 122/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0405 - val_loss: 0.0467
# Epoch 123/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0382 - val_loss: 0.2033
# Epoch 124/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0356 - val_loss: 0.1120
# Epoch 125/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0388 - val_loss: 0.0722
# Epoch 126/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0384 - val_loss: 0.1080
# Epoch 127/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0361 - val_loss: 0.0584
# Epoch 128/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0371 - val_loss: 0.0952
# Epoch 129/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0385 - val_loss: 0.1163
# Epoch 130/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0420 - val_loss: 0.1110
# Epoch 131/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0360 - val_loss: 0.0996
# Epoch 132/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0457 - val_loss: 0.1228
# Epoch 133/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0393 - val_loss: 0.0774
# Epoch 134/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0396 - val_loss: 0.0384
# Epoch 135/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0336 - val_loss: 0.0696
# Epoch 136/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0351 - val_loss: 0.1031
# Epoch 137/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0360 - val_loss: 0.1181
# Epoch 138/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0324 - val_loss: 0.1596
# Epoch 139/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0347 - val_loss: 0.1386
# Epoch 140/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0361 - val_loss: 0.1329
# Epoch 141/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0360 - val_loss: 0.1583
# Epoch 142/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0392 - val_loss: 0.0504
# Epoch 143/250
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0434 - val_loss: 0.1436
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 2026/06/21 08:19:10 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run loud-fowl-851 at: http://localhost:5000/#/experiments/1/runs/2b044b12f2dd4051ad0e1e2ab00370f5
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# r2_train:   0.97682
# r2_test:    0.79843
# rmse_train: 3.7784
# rmse_test:  3.973

# %%
n_splits = 5 # Assuming n_splits is 5 as used in previous CV
kf_time_series_reget = TimeSeriesSplit(n_splits=n_splits)

last_train_index = None
last_test_index = None
last_y_train_fold = None
last_y_test_fold = None
last_scaler_y_cv = None

# Iterate through the splits to get the data and scaler for the last fold
# X_recent_2d is assumed to be available from prior cells.
for i, (tr_idx, ts_idx) in enumerate(kf_time_series_reget.split(X_recent_2d)):
    if i == n_splits - 1: # This is the last fold which is fold 5
        last_train_index = tr_idx
        last_test_index = ts_idx
        last_y_train_fold = y_recent[tr_idx]
        last_y_test_fold = y_recent[ts_idx]

        # Recreate scaler_y_cv for the last fold to ensure consistency
        temp_scaler_y_cv = MinMaxScaler(feature_range=(0,1))
        temp_scaler_y_cv.fit(last_y_train_fold.reshape(-1, 1))
        last_scaler_y_cv = temp_scaler_y_cv
        break


y_train_pred_scaled = model_lstm_final.predict(X_train_scaled_3d_cv)
y_test_pred_scaled  = model_lstm_final.predict(X_test_scaled_3d_cv)

# Inverse transform predictions to original scale using the correct scaler_y_cv
y_train_pred = last_scaler_y_cv.inverse_transform(y_train_pred_scaled)
y_test_pred  = last_scaler_y_cv.inverse_transform(y_test_pred_scaled)

# Now use the true values and dates from the last fold's split
y_train_true = last_y_train_fold.reshape(-1, 1)
y_test_true = last_y_test_fold.reshape(-1, 1)
dates_train_plot = dates_recent[last_train_index]
dates_test_plot = dates_recent[last_test_index]

# Create a figure with one subplot for loss
fig, ax = plt.subplots(1, 1, figsize=(6, 4))

# Plot Training and Validation Loss
ax.plot(history_lstm_final.history['loss'], label='Training Loss')
ax.plot(history_lstm_final.history['val_loss'], label='Validation Loss')
ax.set_title('Training and Validation Loss (LSTM)')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
plt.tight_layout()
plt.show()

# Calculate metrics for LSTM model
r2_train = r2_score(y_train_true, y_train_pred)
print(f'r2_train:   {r2_train:.5}')

r2_test = r2_score(y_test_true, y_test_pred)
print(f'r2_test:    {r2_test:.5}')

rmse_train = mean_squared_error(y_train_true, y_train_pred)**0.5
print(f'rmse_train: {rmse_train:.5}')

rmse_test = mean_squared_error(y_test_true, y_test_pred)**0.5
print(f'rmse_test:  {rmse_test:.5}')

# Convert predictions to pandas Series with dates as index for plotting
y_train_pred_series = pd.Series(y_train_pred.flatten(), index=dates_train_plot)
y_test_pred_series  = pd.Series(y_test_pred.flatten(), index=dates_test_plot)

# Calculate global y-axis limits for consistent plotting
y_min = min(y_train_true.min(), y_train_pred_series.min(), y_test_true.min(), y_test_pred_series.min())
y_max = max(y_train_true.max(), y_train_pred_series.max(), y_test_true.max(), y_test_pred_series.max())

# Plot train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train_plot, y_train_true, 'r', label='True')
axs[0].plot(y_train_pred_series, 'g', label='Predicted')
axs[0].set_title('Train Set (LSTM)')
axs[0].set_ylim(y_min, y_max)
axs[0].legend()

axs[1].plot(dates_test_plot, y_test_true, 'r', label='True')
axs[1].plot(y_test_pred_series, 'g', label='Predicted')
axs[1].set_title('Test Set (LSTM)')
axs[1].set_ylim(y_min, y_max)
axs[1].legend()

plt.tight_layout()
plt.show()

# Plot scatter plots for train and test side by side with shared y limits
fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train_true, y_train_pred_series.values, 'c.')
axs[0].set_title('Train Set (LSTM)')
axs[0].set_xlabel('True Values')
axs[0].set_ylabel('Predicted Values')
# axs[0].legend() # Removed as there's no label for scatter plot

axs[1].plot(y_test_true, y_test_pred_series.values, 'c.')
axs[1].set_title('Test Set (LSTM)')
axs[1].set_xlabel('True Values')
axs[1].set_ylabel('Predicted Values')
# axs[1].legend() # Removed as there's no label for scatter plot

plt.tight_layout()
plt.show()

mae_train = mean_absolute_error(y_train_true, y_train_pred)
mae_test = mean_absolute_error(y_test_true, y_test_pred)

print("MAE:")
print(f"  Train: {mae_train:.4f}")
print(f"  Test:  {mae_test:.4f}")
print("R^2:")
print(f"  Train: {r2_train:.4f}")
print(f"  Test:  {r2_test:.4f}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# r2_train:   0.97682
# r2_test:    0.79843
# rmse_train: 3.7784
# rmse_test:  3.973
# MAE:
#   Train: 2.7614
#   Test:  2.9709
# R^2:
#   Train: 0.9768
#   Test:  0.7984

# %%
# Create a DataFrame to organize the data of true vs pred data graph
predicted_results_df_corrected = pd.DataFrame({
    'Actual Close Price': pd.Series(y_test_true.flatten(), index=dates_test_plot), # Use y_test_true and dates_test_plot
    'Predicted Stock Price': pd.Series(y_test_pred.flatten(), index=dates_test_plot),
    'Difference (Error)': (pd.Series(y_test_true.flatten(), index=dates_test_plot) - pd.Series(y_test_pred.flatten(), index=dates_test_plot)),
    'Percentage Error (%)': ((abs(pd.Series(y_test_true.flatten(), index=dates_test_plot) - pd.Series(y_test_pred.flatten(), index=dates_test_plot))) / pd.Series(y_test_true.flatten(), index=dates_test_plot)) * 100
})

# Get the original 'Open' prices from the stocks DataFrame using dates_test_plot's index
# Note: 'stocks' DataFrame has 'Open' (capital O) column
open_prices = stocks.loc[dates_test_plot, ['Open']]

# Merge this information into predicted_results_df, aligning by index
predicted_results_df_corrected = predicted_results_df_corrected.merge(open_prices, left_index=True, right_index=True)

# Reorder columns for clarity, putting 'Open' and 'Actual Close Price' first
predicted_results_df_corrected = predicted_results_df_corrected[[
    'Open', 'Actual Close Price', 'Predicted Stock Price',
    'Difference (Error)', 'Percentage Error (%)'
]]

# Sort the DataFrame by its index (dates) to enable proper time-series slicing
predicted_results_df_corrected = predicted_results_df_corrected.sort_index()

# Display the corrected numerical table filtered from 2007 to 2026
display(predicted_results_df_corrected.loc['2025':'2026'])
# Out:
#                   Open  Actual Close Price  Predicted Stock Price  \
# 2025-10-31  276.463053          276.792443             269.862854
# 2025-11-03  269.905566          270.334741             271.506287
# 2025-11-04  267.819507          270.973499             270.145721
# 2025-11-05  268.098980          271.183128             270.128693
# 2025-11-06  267.380377          272.879874             270.383636
# ...                ...                 ...                    ...
# 2026-03-12  258.660004          258.950012             259.884277
# 2026-03-13  255.479996          256.329987             256.804474
# 2026-03-16  252.110001          253.889999             252.282944
# 2026-03-17  252.960007          255.130005             250.544174
# 2026-03-18  252.625000          254.940002             250.285446
#
#             Difference (Error)  Percentage Error (%)
# 2025-10-31            6.929589              2.503532
# 2025-11-03           -1.171546              0.433369
# 2025-11-04            0.827777              0.305483
# 2025-11-05            1.054436              0.388828
# 2025-11-06            2.496238              0.914775
# ...                        ...                   ...
# 2026-03-12           -0.934265              0.360790
# 2026-03-13           -0.474487              0.185108
# 2026-03-16            1.607056              0.632973
# 2026-03-17            4.585831              1.797449
# 2026-03-18            4.654556              1.825746
#
# [94 rows x 5 columns]

# %% [markdown]
# ### Saving the Trained Model and Scalers
# Save the retrained LSTM model (`lstm_model.keras`), the fitted X-scaler (`scaler_X.pkl`), and the fitted y-scaler (`scaler_y.pkl`) to project directory. These files can be loaded later to make new predictions without retraining or re-fitting the scalers. This uses the last fold (fold 5) of the cross validation

# %%
'''# Save the LSTM model
model_lstm_final.save('lstm_model.keras')
print("LSTM model saved as 'lstm_model.keras'")

# Save the X scaler
joblib.dump(scaler_X_final, 'scaler_X.pkl')
print("X scaler saved as 'scaler_X.pkl'")

# Save the y scaler
joblib.dump(scaler_y_final, 'scaler_y.pkl')
print("Y scaler saved as 'scaler_y.pkl'")'''
# Out:
# '# Save the LSTM model\nmodel_lstm_final.save(\'lstm_model.keras\')\nprint("LSTM model saved as \'lstm_model.keras\'")\n\n# Save the X scaler\njoblib.dump(scaler_X_final, \'scaler_X.pkl\')\nprint("X scaler saved as \'scaler_X.pkl\'")\n\n# Save the y scaler\njoblib.dump(scaler_y_final, \'scaler_y.pkl\')\nprint("Y scaler saved as \'scaler_y.pkl\'")'

# %% [markdown]
# ### Training model_lstm_final on a Specific Fold (e.g., Fold 4)
#
# To demonstrate how to train and evaluate the model_lstm_final on a specific fold, we will perform the following steps for **Fold 4**:
#
# 1.  **Iterate through the TimeSeriesSplit** to get the train_index and test_index for Fold 4.
# 2.  **Extract the data** (X_train_fold_4, y_train_fold_4, X_test_fold_4, y_test_fold_4, dates_train_fold_4, dates_test_fold_4).
# 3.  **Scale the data** using new MinMaxScaler instances (scaler_X_fold_4, scaler_y_fold_4) to prevent data leakage from other folds.
# 4.  **Reshape the scaled X data** to the 3D format required by the LSTM model.
# 5.  **Build a fresh model_lstm_final** with its optimizer and compile it.
# 6.  **Train the model** using the specific fold's scaled data.
# 7.  **Evaluate and plot the results** for Fold 4.

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# Define the LSTM model building function
def build_lstm_model(window_size, num_features, dropout_rate=0.2, learning_rate=0.001):
    model = Sequential([
        Input(shape=(window_size, num_features)),
        LSTM(64, return_sequences=True),
        Dropout(dropout_rate),
        BatchNormalization(),
        LSTM(32, return_sequences=False),
        Dropout(dropout_rate),
        Dense(32, activation='relu'),
        Dense(1)
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='mae')
    return model

# Re-initialize TimeSeriesSplit
n_splits = 5
kf_time_series = TimeSeriesSplit(n_splits=n_splits)

# X_recent_2d was already created in cell 5fe8341e
# We will iterate to get the 4th fold's indices

selected_fold = 4
current_fold = 0

for train_index, test_index in kf_time_series.split(X_recent_2d):
    current_fold += 1
    if current_fold == selected_fold:
        # Store the indices for the selected fold
        train_index_4 = train_index
        test_index_4 = test_index
        break

print(f"Extracted indices for Fold {selected_fold}")

# Extract data for Fold 4
X_train_fold_4_2d = X_recent_2d[train_index_4]
X_test_fold_4_2d  = X_recent_2d[test_index_4]
y_train_fold_4    = y_recent[train_index_4]
y_test_fold_4     = y_recent[test_index_4]
dates_train_fold_4 = dates_recent[train_index_4]
dates_test_fold_4  = dates_recent[test_index_4]

# Scale data for Fold 4
scaler_X_fold_4 = MinMaxScaler(feature_range=(0, 1))
scaler_y_fold_4 = MinMaxScaler(feature_range=(0, 1))

X_train_scaled_fold_4_2d = scaler_X_fold_4.fit_transform(X_train_fold_4_2d)
X_test_scaled_fold_4_2d  = scaler_X_fold_4.transform(X_test_fold_4_2d)

y_train_scaled_fold_4 = scaler_y_fold_4.fit_transform(y_train_fold_4.reshape(-1, 1))
y_test_scaled_fold_4  = scaler_y_fold_4.transform(y_test_fold_4.reshape(-1, 1))

# Reshape scaled X data to 3D for LSTM input
current_window_size = X_recent.shape[1] # This should be 10
current_num_features = X_recent.shape[2] # This should be 5

X_train_scaled_3d_fold_4 = X_train_scaled_fold_4_2d.reshape((X_train_scaled_fold_4_2d.shape[0], current_window_size, current_num_features))
X_test_scaled_3d_fold_4  = X_test_scaled_fold_4_2d.reshape((X_test_scaled_fold_4_2d.shape[0], current_window_size, current_num_features))

print("Data for Fold 4 prepared and scaled.")

# Build a fresh model for Fold 4
model_lstm_fold_4 = build_lstm_model(
    current_window_size,
    current_num_features,
    dropout_rate=0.2,
    learning_rate=0.001 # Use the optimized learning rate
)

# Early stopping callback
early_stopping_fold_4 = EarlyStopping(
    monitor='val_loss',
    patience=25,
    restore_best_weights=True
)

print(f"\nTraining model for Fold {selected_fold}...")
history_lstm_fold_4 = model_lstm_fold_4.fit(
    X_train_scaled_3d_fold_4, y_train_scaled_fold_4,
    epochs=250,
    batch_size=64,
    validation_data=(X_test_scaled_3d_fold_4, y_test_scaled_fold_4),
    verbose=1,
    callbacks=[early_stopping_fold_4]
)

print(f"\nEvaluation for Fold {selected_fold}:")
# Get predictions
y_train_pred_scaled_fold_4 = model_lstm_fold_4.predict(X_train_scaled_3d_fold_4)
y_test_pred_scaled_fold_4  = model_lstm_fold_4.predict(X_test_scaled_3d_fold_4)

# Inverse transform predictions to original scale
y_train_pred_fold_4 = scaler_y_fold_4.inverse_transform(y_train_pred_scaled_fold_4)
y_test_pred_fold_4  = scaler_y_fold_4.inverse_transform(y_test_pred_scaled_fold_4)

# Calculate metrics
r2_train_fold_4 = r2_score(y_train_fold_4, y_train_pred_fold_4)
r2_test_fold_4  = r2_score(y_test_fold_4, y_test_pred_fold_4)

rmse_train_fold_4 = mean_squared_error(y_train_fold_4, y_train_pred_fold_4)**0.5
rmse_test_fold_4  = mean_squared_error(y_test_fold_4, y_test_pred_fold_4)**0.5

mae_train_fold_4 = mean_absolute_error(y_train_fold_4, y_train_pred_fold_4)
mae_test_fold_4  = mean_absolute_error(y_test_fold_4, y_test_pred_fold_4)

print("MAE:")
print(f"  Train: {mae_train_fold_4:.4f}")
print(f"  Test:  {mae_test_fold_4:.4f}")
print("R^2:")
print(f"  Train: {r2_train_fold_4:.4f}")
print(f"  Test:  {r2_test_fold_4:.4f}")

# Plotting for Fold 4
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
ax.plot(history_lstm_fold_4.history['loss'], label='Training Loss')
ax.plot(history_lstm_fold_4.history['val_loss'], label='Validation Loss')
ax.set_title(f'Training and Validation Loss (LSTM) - Fold {selected_fold}')
ax.set_xlabel('Epochs')
ax.set_ylabel('Loss')
ax.legend()
plt.tight_layout()
plt.show()

y_train_pred_series_fold_4 = pd.Series(y_train_pred_fold_4.flatten(), index=dates_train_fold_4)
y_test_pred_series_fold_4  = pd.Series(y_test_pred_fold_4.flatten(), index=dates_test_fold_4)

y_min_fold_4 = min(y_train_fold_4.min(), y_train_pred_series_fold_4.min(), y_test_fold_4.min(), y_test_pred_series_fold_4.min())
y_max_fold_4 = max(y_train_fold_4.max(), y_train_pred_series_fold_4.max(), y_test_fold_4.max(), y_test_pred_series_fold_4.max())

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(dates_train_fold_4, y_train_fold_4, 'r', label='True')
axs[0].plot(y_train_pred_series_fold_4, 'g', label='Predicted')
axs[0].set_title(f'Train Set (LSTM) - Fold {selected_fold}')
axs[0].set_ylim(y_min_fold_4, y_max_fold_4)
axs[0].legend()

axs[1].plot(dates_test_fold_4, y_test_fold_4, 'r', label='True')
axs[1].plot(y_test_pred_series_fold_4, 'g', label='Predicted')
axs[1].set_title(f'Test Set (LSTM) - Fold {selected_fold}')
axs[1].set_ylim(y_min_fold_4, y_max_fold_4)
axs[1].legend()

plt.tight_layout()
plt.show()

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

axs[0].plot(y_train_fold_4, y_train_pred_series_fold_4.values, 'c.')
axs[0].set_title(f'Train Set (LSTM) - Fold {selected_fold}')
axs[0].set_xlabel('True Values')
axs[0].set_ylabel('Predicted Values')

axs[1].plot(y_test_fold_4, y_test_pred_series_fold_4.values, 'c.')
axs[1].set_title(f'Test Set (LSTM) - Fold {selected_fold}')
axs[1].set_xlabel('True Values')
axs[1].set_ylabel('Predicted Values')

plt.tight_layout()
plt.show()
# Out:
# 2026/06/21 08:22:25 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '70358c1d22ed4df19978ae6ca889c1cd', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current tensorflow workflow
# Extracted indices for Fold 4
# Data for Fold 4 prepared and scaled.
#
# Training model for Fold 4...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Epoch 1/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - loss: 0.5482
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.3203 - val_loss: 0.4625
# Epoch 2/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1354
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1470 - val_loss: 0.3741
# Epoch 3/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1293 - val_loss: 0.3899
# Epoch 4/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0998
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1152 - val_loss: 0.3481
# Epoch 5/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1178
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1045 - val_loss: 0.3277
# Epoch 6/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1050 - val_loss: 0.3586
# Epoch 7/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1026 - val_loss: 0.3498
# Epoch 8/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0953 - val_loss: 0.3429
# Epoch 9/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0889 - val_loss: 0.3552
# Epoch 10/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0848 - val_loss: 0.3554
# Epoch 11/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0834 - val_loss: 0.3571
# Epoch 12/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0748 - val_loss: 0.3551
# Epoch 13/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0795 - val_loss: 0.3424
# Epoch 14/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0841 - val_loss: 0.3642
# Epoch 15/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0810 - val_loss: 0.3550
# Epoch 16/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0812
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0802 - val_loss: 0.3245
# Epoch 17/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0778 - val_loss: 0.3348
# Epoch 18/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0661
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0743 - val_loss: 0.3187
# Epoch 19/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0701 - val_loss: 0.3203
# Epoch 20/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0731 - val_loss: 0.3238
# Epoch 21/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0729
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0716 - val_loss: 0.3121
# Epoch 22/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0801
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0694 - val_loss: 0.3061
# Epoch 23/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0650 - val_loss: 0.3148
# Epoch 24/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0669 - val_loss: 0.3124
# Epoch 25/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0970
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0695 - val_loss: 0.3000
# Epoch 26/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0633
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0685 - val_loss: 0.2807
# Epoch 27/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0770
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0677 - val_loss: 0.2526
# Epoch 28/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0724 - val_loss: 0.2603
# Epoch 29/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0651 - val_loss: 0.2639
# Epoch 30/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0699 - val_loss: 0.2840
# Epoch 31/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0623 - val_loss: 0.2779
# Epoch 32/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0610 - val_loss: 0.2976
# Epoch 33/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0601 - val_loss: 0.2806
# Epoch 34/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0603 - val_loss: 0.2879
# Epoch 35/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0590 - val_loss: 0.2720
# Epoch 36/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0643 - val_loss: 0.2556
# Epoch 37/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0606
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0620 - val_loss: 0.2455
# Epoch 38/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0569 - val_loss: 0.2484
# Epoch 39/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0618 - val_loss: 0.2617
# Epoch 40/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0516 - val_loss: 0.2729
# Epoch 41/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0526 - val_loss: 0.2708
# Epoch 42/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0559 - val_loss: 0.2744
# Epoch 43/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0596 - val_loss: 0.2559
# Epoch 44/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0568 - val_loss: 0.2557
# Epoch 45/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0485
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0531 - val_loss: 0.2318
# Epoch 46/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0552 - val_loss: 0.2342
# Epoch 47/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0546 - val_loss: 0.2351
# Epoch 48/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0485
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0560 - val_loss: 0.2081
# Epoch 49/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0525 - val_loss: 0.2386
# Epoch 50/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0503
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0519 - val_loss: 0.1986
# Epoch 51/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0554 - val_loss: 0.2587
# Epoch 52/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0561 - val_loss: 0.2250
# Epoch 53/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0538 - val_loss: 0.2442
# Epoch 54/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0587 - val_loss: 0.2403
# Epoch 55/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0582 - val_loss: 0.2269
# Epoch 56/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0606 - val_loss: 0.2470
# Epoch 57/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0558 - val_loss: 0.2358
# Epoch 58/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0498 - val_loss: 0.2516
# Epoch 59/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0573 - val_loss: 0.2360
# Epoch 60/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0536 - val_loss: 0.2209
# Epoch 61/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0527 - val_loss: 0.2037
# Epoch 62/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0540
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0522 - val_loss: 0.1707
# Epoch 63/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0501 - val_loss: 0.1840
# Epoch 64/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0494
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0567 - val_loss: 0.1686
# Epoch 65/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0458 - val_loss: 0.1819
# Epoch 66/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0486 - val_loss: 0.1960
# Epoch 67/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0467 - val_loss: 0.1751
# Epoch 68/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0512 - val_loss: 0.2143
# Epoch 69/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0512 - val_loss: 0.1689
# Epoch 70/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0507 - val_loss: 0.1800
# Epoch 71/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0482 - val_loss: 0.1695
# Epoch 72/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0497 - val_loss: 0.1734
# Epoch 73/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0519
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0460 - val_loss: 0.1650
# Epoch 74/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0455 - val_loss: 0.1933
# Epoch 75/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0431
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0501 - val_loss: 0.1386
# Epoch 76/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0479 - val_loss: 0.1824
# Epoch 77/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0475 - val_loss: 0.1508
# Epoch 78/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0455 - val_loss: 0.1846
# Epoch 79/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0470 - val_loss: 0.1497
# Epoch 80/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0476 - val_loss: 0.1691
# Epoch 81/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0445 - val_loss: 0.1431
# Epoch 82/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0436 - val_loss: 0.1430
# Epoch 83/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0428 - val_loss: 0.1391
# Epoch 84/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0426 - val_loss: 0.1599
# Epoch 85/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0460 - val_loss: 0.1461
# Epoch 86/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0437 - val_loss: 0.1498
# Epoch 87/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0449 - val_loss: 0.1447
# Epoch 88/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0481 - val_loss: 0.1387
# Epoch 89/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0509
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0451 - val_loss: 0.1196
# Epoch 90/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0376
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0429 - val_loss: 0.1185
# Epoch 91/250
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0450
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0429 - val_loss: 0.0955
# Epoch 92/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0419 - val_loss: 0.1270
# Epoch 93/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0449 - val_loss: 0.1220
# Epoch 94/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0467 - val_loss: 0.1109
# Epoch 95/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0474 - val_loss: 0.1275
# Epoch 96/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0501 - val_loss: 0.1108
# Epoch 97/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0538 - val_loss: 0.1549
# Epoch 98/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0404 - val_loss: 0.1220
# Epoch 99/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0408 - val_loss: 0.1214
# Epoch 100/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0452 - val_loss: 0.1208
# Epoch 101/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0448 - val_loss: 0.1309
# Epoch 102/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0413 - val_loss: 0.1427
# Epoch 103/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0412 - val_loss: 0.1253
# Epoch 104/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0419 - val_loss: 0.1224
# Epoch 105/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0395 - val_loss: 0.1137
# Epoch 106/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0460 - val_loss: 0.1207
# Epoch 107/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0372 - val_loss: 0.1149
# Epoch 108/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0435 - val_loss: 0.1567
# Epoch 109/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0466 - val_loss: 0.1003
# Epoch 110/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0419 - val_loss: 0.1380
# Epoch 111/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0420 - val_loss: 0.1036
# Epoch 112/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0392 - val_loss: 0.1337
# Epoch 113/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0383 - val_loss: 0.1008
# Epoch 114/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0434 - val_loss: 0.1232
# Epoch 115/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0359 - val_loss: 0.1104
# Epoch 116/250
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0423 - val_loss: 0.1093
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 2026/06/21 08:22:40 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run respected-mule-686 at: http://localhost:5000/#/experiments/1/runs/70358c1d22ed4df19978ae6ca889c1cd
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
#
# Evaluation for Fold 4:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# MAE:
#   Train: 5.1200
#   Test:  8.9561
# R^2:
#   Train: 0.9240
#   Test:  0.6760

# %% [markdown]
# ### Saving the Trained Model for Specific Fold (e.g., Fold 4)
#
# Now, we will save the `model_lstm_fold_4` which was specifically trained and evaluated on **Fold 4**. This allows you to retain the model's weights and configuration from this particular cross-validation split.

# %%
import joblib
model_lstm_fold_4.save('lstm_model_fold_4.keras')
print("LSTM model for Fold 4 saved as 'lstm_model_fold_4.keras'")

# Save the X scaler specific to Fold 4
joblib.dump(scaler_X_fold_4, 'scaler_X_fold_4.pkl')
print("X scaler for Fold 4 saved as 'scaler_X_fold_4.pkl'")

# Save the y scaler specific to Fold 4
joblib.dump(scaler_y_fold_4, 'scaler_y_fold_4.pkl')
print("Y scaler for Fold 4 saved as 'scaler_y_fold_4.pkl'")
# Out:
# LSTM model for Fold 4 saved as 'lstm_model_fold_4.keras'
# X scaler for Fold 4 saved as 'scaler_X_fold_4.pkl'
# Y scaler for Fold 4 saved as 'scaler_y_fold_4.pkl'

# %% [markdown]
# ### MLflow Tracking Example for LSTM Model
#
# Logging LSTM model's training details, parameters, and performance metrics to MLflow. The results from the `model_lstm_fold_4` which was trained on Fold 4 of the time series cross-validation.

# %%
'''import mlflow
import mlflow.keras
from sklearn.metrics import mean_absolute_error, r2_score

# Set an experiment name for the LSTM model
mlflow.set_experiment("Stock Price Prediction - LSTM Model")

with mlflow.start_run():
    # Log parameters specific to the LSTM model (from build_lstm_model and training for Fold 4)
    mlflow.log_param("epochs", 250)
    mlflow.log_param("batch_size", 64)
    mlflow.log_param("dropout_rate", 0.2)
    mlflow.log_param("learning_rate", 0.001)
    mlflow.log_param("loss_function", "mae")
    mlflow.log_param("window_size", 10)
    mlflow.log_param("num_features", X_recent.shape[2]) # Get from X_recent as used in CV

    # Log metrics (using the results from the Fold 4 evaluation)
    mlflow.log_metric("train_mae", mae_train_fold_4)
    mlflow.log_metric("test_mae", mae_test_fold_4)
    mlflow.log_metric("train_r2", r2_train_fold_4)
    mlflow.log_metric("test_r2", r2_test_fold_4)
    mlflow.log_metric("train_rmse", rmse_train_fold_4)
    mlflow.log_metric("test_rmse", rmse_test_fold_4)

    # Log the Keras LSTM model for Fold 4
    mlflow.keras.log_model(model_lstm_fold_4, "lstm_model_fold_4")

    print("MLflow Run for LSTM model completed.")'''
# Out:
# 'import mlflow\nimport mlflow.keras\nfrom sklearn.metrics import mean_absolute_error, r2_score\n\n# Set an experiment name for the LSTM model\nmlflow.set_experiment("Stock Price Prediction - LSTM Model")\n\nwith mlflow.start_run():\n    # Log parameters specific to the LSTM model (from build_lstm_model and training for Fold 4)\n    mlflow.log_param("epochs", 250)\n    mlflow.log_param("batch_size", 64)\n    mlflow.log_param("dropout_rate", 0.2)\n    mlflow.log_param("learning_rate", 0.001)\n    mlflow.log_param("loss_function", "mae")\n    mlflow.log_param("window_size", 10)\n    mlflow.log_param("num_features", X_recent.shape[2]) # Get from X_recent as used in CV\n\n    # Log metrics (using the results from the Fold 4 evaluation)\n    mlflow.log_metric("train_mae", mae_train_fold_4)\n    mlflow.log_metric("test_mae", mae_test_fold_4)\n    mlflow.log_metric("train_r2", r2_train_fold_4)\n    mlflow.log_metric("test_r2", r2_test_fold_4)\n    mlflow.log_metric("train_rmse", rmse_train_fold_4)\n    mlflow.log_metric("test_rmse", rmse_test_fold_4)\n\n    # Log the Keras LSTM model for Fold 4\n    mlflow.keras.log_model(model_lstm_fold_4, "lstm_model_fold_4")\n\n    print("MLflow Run for LSTM model completed.")'

# %%
# !pip install mlflow cryptography==43.0.3 --ignore-installed blinker
# Out:
# Collecting mlflow
#   Downloading mlflow-3.14.0-py3-none-any.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 4.6 MB/s eta 0:00:00
# Collecting cryptography==43.0.3
#   Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Collecting blinker
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting cffi>=1.12 (from cryptography==43.0.3)
#   Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.6 kB)
# Collecting mlflow-skinny==3.14.0 (from mlflow)
#   Downloading mlflow_skinny-3.14.0-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 5.7 MB/s eta 0:00:00
# Collecting mlflow-tracing==3.14.0 (from mlflow)
#   Downloading mlflow_tracing-3.14.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Downloading flask_cors-6.0.5-py3-none-any.whl.metadata (5.4 kB)
# Collecting Flask<4 (from mlflow)
#   Downloading flask-3.1.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting aiohttp<4,>=3.7.0 (from mlflow)
#   Downloading aiohttp-3.14.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.3 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.18.4-py3-none-any.whl.metadata (7.2 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<27 (from mlflow)
#   Downloading gunicorn-26.0.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting huey<4,>=2.5.4 (from mlflow)
#   Downloading huey-3.0.3-py3-none-any.whl.metadata (4.5 kB)
# Collecting matplotlib<4 (from mlflow)
#   Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 9.4 MB/s eta 0:00:00
# Collecting numpy<3 (from mlflow)
#   Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pandas<3 (from mlflow)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 11.8 MB/s eta 0:00:00
# Collecting pyarrow<25,>=4.0.0 (from mlflow)
#   Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting scikit-learn<2 (from mlflow)
#   Downloading scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Collecting scipy<2 (from mlflow)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.6 MB/s eta 0:00:00
# Collecting skops<1 (from mlflow)
#   Downloading skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow)
#   Downloading sqlalchemy-2.0.51-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting cachetools<8,>=5.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading cachetools-7.1.4-py3-none-any.whl.metadata (5.5 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading click-8.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting cloudpickle<4 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading databricks_sdk-0.118.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.5 MB/s eta 0:00:00
# Collecting fastapi<1 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading fastapi-0.138.0-py3-none-any.whl.metadata (27 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading gitpython-3.1.50-py3-none-any.whl.metadata (14 kB)
# Collecting importlib_metadata!=4.7.0,<10,>=3.7.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading opentelemetry_api-1.42.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading opentelemetry_proto-1.42.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading opentelemetry_sdk-1.42.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting packaging<27 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading protobuf-7.35.1-cp310-abi3-manylinux2014_x86_64.whl.metadata (595 bytes)
# Collecting pydantic<3,>=2.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading pydantic-2.13.4-py3-none-any.whl.metadata (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.4/109.4 kB 13.4 MB/s eta 0:00:00
# Collecting python-dotenv<2,>=0.19.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting starlette<2 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading starlette-1.3.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting uvicorn<1 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading uvicorn-0.49.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4,>=3.7.0->mlflow)
#   Downloading yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (94 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 9.9 MB/s eta 0:00:00
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading mako-1.3.12-py3-none-any.whl.metadata (2.9 kB)
# Collecting pycparser (from cffi>=1.12->cryptography==43.0.3)
#   Downloading pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow)
#   Downloading urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting jinja2>=3.1.2 (from Flask<4->mlflow)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<4->mlflow)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow)
#   Downloading werkzeug-3.1.8-py3-none-any.whl.metadata (4.0 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.11-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting python-dateutil<3,>=2.7.0 (from graphene<4->mlflow)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 12.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting pillow>=9 (from matplotlib<4->mlflow)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib<4->mlflow)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting pytz>=2020.1 (from pandas<3->mlflow)
#   Downloading pytz-2026.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas<3->mlflow)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.4.0 (from scikit-learn<2->mlflow)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn<2->mlflow)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn<2->mlflow)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow)
#   Downloading greenlet-3.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading google_auth-2.55.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.14.0->mlflow)
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting typing-inspection>=0.4.2 (from fastapi<1->mlflow-skinny==3.14.0->mlflow)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.14.0->mlflow)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading zipp-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting opentelemetry-semantic-conventions==0.63b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl.metadata (2.4 kB)
# Collecting wcwidth (from prettytable>=3.9->skops<1->mlflow)
#   Downloading wcwidth-0.8.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.1/43.1 kB 4.6 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.4 (from pydantic<3,>=2.0.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil<3,>=2.7.0->graphene<4->mlflow)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 4.2 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Downloading idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting certifi>=2023.5.7 (from requests<3,>=2.17.3->mlflow-skinny==3.14.0->mlflow)
#   Downloading certifi-2026.6.17-py3-none-any.whl.metadata (2.5 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<2->mlflow-skinny==3.14.0->mlflow)
#   Downloading anyio-4.14.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==3.14.0->mlflow)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.14.0->mlflow)
#   Downloading smmap-5.0.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.14.0->mlflow)
#   Downloading pyasn1-0.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 122.5 MB/s eta 0:00:00
# Downloading mlflow-3.14.0-py3-none-any.whl (12.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 219.7 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.14.0-py3-none-any.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 164.9 MB/s eta 0:00:00
# Downloading mlflow_tracing-3.14.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 123.2 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading aiohttp-3.14.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 127.4 MB/s eta 0:00:00
# Downloading alembic-1.18.4-py3-none-any.whl (263 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 263.9/263.9 kB 32.3 MB/s eta 0:00:00
# Downloading cffi-2.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.6/219.6 kB 27.2 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 18.3 MB/s eta 0:00:00
# Downloading flask-3.1.3-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.4/103.4 kB 12.7 MB/s eta 0:00:00
# Downloading flask_cors-6.0.5-py3-none-any.whl (16 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 17.2 MB/s eta 0:00:00
# Downloading gunicorn-26.0.0-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.0/212.0 kB 22.6 MB/s eta 0:00:00
# Downloading huey-3.0.3-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 10.8 MB/s eta 0:00:00
# Downloading matplotlib-3.11.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 231.2 MB/s eta 0:00:00
# Downloading numpy-2.4.6-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 192.6 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 224.3 MB/s eta 0:00:00
# Downloading pyarrow-24.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (48.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 94.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.9.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 210.5 MB/s eta 0:00:00
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 136.2 MB/s eta 0:00:00
# Downloading skops-0.14.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.2/132.2 kB 13.8 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.51-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 174.0 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.5/67.5 kB 8.3 MB/s eta 0:00:00
# Downloading cachetools-7.1.4-py3-none-any.whl (16 kB)
# Downloading click-8.4.1-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 kB 14.4 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 38.8 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading databricks_sdk-0.118.0-py3-none-any.whl (939 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 kB 84.7 MB/s eta 0:00:00
# Downloading fastapi-0.138.0-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 14.2 MB/s eta 0:00:00
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 195.7 MB/s eta 0:00:00
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 27.4 MB/s eta 0:00:00
# Downloading gitpython-3.1.50-py3-none-any.whl (212 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 25.3 MB/s eta 0:00:00
# Downloading graphql_core-3.2.11-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 22.9 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading greenlet-3.5.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.7/613.7 kB 60.6 MB/s eta 0:00:00
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 14.7 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 31.8 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 112.5 MB/s eta 0:00:00
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading multidict-6.7.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.3/256.3 kB 27.9 MB/s eta 0:00:00
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 454.8/454.8 kB 43.2 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.42.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 7.0 MB/s eta 0:00:00
# Downloading opentelemetry_proto-1.42.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 7.8 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.42.1-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 19.3 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.63b1-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 23.1 MB/s eta 0:00:00
# Downloading packaging-26.2-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 10.6 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 197.3 MB/s eta 0:00:00
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading propcache-0.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 6.9 MB/s eta 0:00:00
# Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.4/323.4 kB 38.2 MB/s eta 0:00:00
# Downloading pydantic-2.13.4-py3-none-any.whl (472 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.3/472.3 kB 50.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.46.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 124.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 15.2 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 26.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading pytz-2026.2-py2.py3-none-any.whl (510 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.1/510.1 kB 56.7 MB/s eta 0:00:00
# Downloading pyyaml-6.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (807 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 807.9/807.9 kB 76.8 MB/s eta 0:00:00
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 7.7 MB/s eta 0:00:00
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 5.4 MB/s eta 0:00:00
# Downloading starlette-1.3.1-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 8.5 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 5.5 MB/s eta 0:00:00
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.3/349.3 kB 38.6 MB/s eta 0:00:00
# Downloading urllib3-2.7.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 15.8 MB/s eta 0:00:00
# Downloading uvicorn-0.49.0-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 8.5 MB/s eta 0:00:00
# Downloading werkzeug-3.1.8-py3-none-any.whl (226 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 28.2 MB/s eta 0:00:00
# Downloading yarl-1.24.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.6/105.6 kB 13.0 MB/s eta 0:00:00
# Downloading mako-1.3.12-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 9.1 MB/s eta 0:00:00
# Downloading pycparser-3.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 5.9 MB/s eta 0:00:00
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading anyio-4.14.0-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 14.8 MB/s eta 0:00:00
# Downloading certifi-2026.6.17-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 16.6 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 25.6 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.7 MB/s eta 0:00:00
# Downloading google_auth-2.55.0-py3-none-any.whl (252 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 29.5 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading idna-3.18-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.3 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading zipp-4.1.0-py3-none-any.whl (10 kB)
# Downloading wcwidth-0.8.1-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.1/323.1 kB 35.6 MB/s eta 0:00:00
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 23.0 MB/s eta 0:00:00
# Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Downloading pyasn1-0.6.3-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: pytz, huey, zipp, wcwidth, urllib3, tzdata, typing-extensions, threadpoolctl, sqlparse, smmap, six, pyyaml, python-dotenv, pyparsing, pycparser, pyasn1, pyarrow, protobuf, propcache, pillow, packaging, numpy, narwhals, multidict, markupsafe, kiwisolver, joblib, itsdangerous, idna, h11, greenlet, graphql-core, frozenlist, fonttools, cycler, cloudpickle, click, charset_normalizer, certifi, cachetools, blinker, attrs, annotated-types, annotated-doc, aiohappyeyeballs, yarl, werkzeug, uvicorn, typing-inspection, sqlalchemy, scipy, requests, python-dateutil, pydantic-core, pyasn1-modules, prettytable, opentelemetry-proto, opentelemetry-api, Mako, jinja2, importlib_metadata, gunicorn, graphql-relay, gitdb, contourpy, cffi, anyio, aiosignal, starlette, scikit-learn, pydantic, pandas, opentelemetry-semantic-conventions, matplotlib, graphene, gitpython, Flask, docker, cryptography, alembic, aiohttp, skops, opentelemetry-sdk, google-auth, Flask-CORS, fastapi, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires google-auth==2.47.0, but you have google-auth 2.55.0 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# Successfully installed Flask-3.1.3 Flask-CORS-6.0.5 Mako-1.3.12 aiohappyeyeballs-2.6.2 aiohttp-3.14.1 aiosignal-1.4.0 alembic-1.18.4 annotated-doc-0.0.4 annotated-types-0.7.0 anyio-4.14.0 attrs-26.1.0 blinker-1.9.0 cachetools-7.1.4 certifi-2026.6.17 cffi-2.0.0 charset_normalizer-3.4.7 click-8.4.1 cloudpickle-3.1.2 contourpy-1.3.3 cryptography-43.0.3 cycler-0.12.1 databricks-sdk-0.118.0 docker-7.1.0 fastapi-0.138.0 fonttools-4.63.0 frozenlist-1.8.0 gitdb-4.0.12 gitpython-3.1.50 google-auth-2.55.0 graphene-3.4.3 graphql-core-3.2.11 graphql-relay-3.2.0 greenlet-3.5.2 gunicorn-26.0.0 h11-0.16.0 huey-3.0.3 idna-3.18 importlib_metadata-9.0.0 itsdangerous-2.2.0 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.5.0 markupsafe-3.0.3 matplotlib-3.11.0 mlflow-3.14.0 mlflow-skinny-3.14.0 mlflow-tracing-3.14.0 multidict-6.7.1 narwhals-2.22.1 numpy-2.4.6 opentelemetry-api-1.42.1 opentelemetry-proto-1.42.1 opentelemetry-sdk-1.42.1 opentelemetry-semantic-conventions-0.63b1 packaging-26.2 pandas-2.3.3 pillow-12.2.0 prettytable-3.17.0 propcache-0.5.2 protobuf-6.33.6 pyarrow-24.0.0 pyasn1-0.6.3 pyasn1-modules-0.4.2 pycparser-3.0 pydantic-2.13.4 pydantic-core-2.46.4 pyparsing-3.3.2 python-dateutil-2.9.0.post0 python-dotenv-1.2.2 pytz-2026.2 pyyaml-6.0.3 requests-2.34.2 scikit-learn-1.9.0 scipy-1.18.0 six-1.17.0 skops-0.14.0 smmap-5.0.3 sqlalchemy-2.0.51 sqlparse-0.5.5 starlette-1.3.1 threadpoolctl-3.6.0 typing-extensions-4.15.0 typing-inspection-0.4.2 tzdata-2026.2 urllib3-2.7.0 uvicorn-0.49.0 wcwidth-0.8.1 werkzeug-3.1.8 yarl-1.24.2 zipp-4.1.0

# %%
import mlflow
import mlflow.keras
import numpy as np
from sklearn.metrics import mean_absolute_error, r2_score
import tensorflow as tf

mlflow.set_experiment("Stock Price Prediction - LSTM Model")

# ── Custom callback to log per-epoch metrics ──────────────────────
class MLflowEpochLogger(tf.keras.callbacks.Callback):
    def __init__(self, fold=None):
        self.fold = fold

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        prefix = f"fold_{self.fold}_" if self.fold is not None else ""
        mlflow.log_metric(f"{prefix}train_loss", logs.get("loss", 0),     step=epoch)
        mlflow.log_metric(f"{prefix}val_loss",   logs.get("val_loss", 0), step=epoch)
        mlflow.log_metric(f"{prefix}train_mae",  logs.get("mae", 0),      step=epoch)
        mlflow.log_metric(f"{prefix}val_mae",    logs.get("val_mae", 0),  step=epoch)

# ── Parent run: wraps all folds ───────────────────────────────────
with mlflow.start_run(run_name="LSTM_CV_All_Folds") as parent_run:

    # Log shared hyperparameters once on the parent
    mlflow.log_params({
        "epochs":        250,
        "batch_size":    64,
        "dropout_rate":  0.2,
        "learning_rate": 0.001,
        "loss_function": "mae",
        "window_size":   10,
        "num_features":  X_recent.shape[2],
        "architecture":  "LSTM(64,ret_seq=True)->BN->Drop(0.2)->LSTM(32)->Drop(0.2)->Dense(32,relu)->Dense(1)"
    })

    # ── Per-fold child runs ───────────────────────────────────────
    fold_results = []

    # The model expects 3D scaled data, and was trained on scaled y.
    # The enumeration now passes the scaled X and scaled y for training,
    # and the original unscaled y values for metric calculation.
    # It also passes the scaler_y_fold_4 to inverse transform predictions.
    for fold_idx, (current_model, X_tr_scaled, y_tr_scaled, X_te_scaled, y_te_scaled, y_tr_original, y_te_original, current_scaler_y) in enumerate([
        (model_lstm_fold_4, X_train_scaled_3d_fold_4, y_train_scaled_fold_4, X_test_scaled_3d_fold_4, y_test_scaled_fold_4, y_train_fold_4, y_test_fold_4, scaler_y_fold_4),
        # Add other folds here if available, following the same pattern:
        # (model_lstm_fold_1, X_train_scaled_3d_fold_1, y_train_scaled_fold_1, X_test_scaled_3d_fold_1, y_test_scaled_fold_1, y_train_fold_1, y_test_fold_1, scaler_y_fold_1),
    ], start=4):  # start=4 since you're logging fold 4 first

        with mlflow.start_run(run_name=f"Fold_{fold_idx}", nested=True):

            # Re-train with the epoch logger so steps are recorded
            # Use scaled X and y data for training
            history = current_model.fit(
                X_tr_scaled, y_tr_scaled,
                validation_data=(X_te_scaled, y_te_scaled),
                epochs=250, # Hyperparameter from parent run
                batch_size=64, # Hyperparameter from parent run
                verbose=0,
                callbacks=[
                    tf.keras.callbacks.EarlyStopping(patience=25, restore_best_weights=True),
                    MLflowEpochLogger(fold=fold_idx)
                ]
            )

            # Final evaluation metrics
            # Predictions are scaled, so inverse transform them
            scaled_train_pred = current_model.predict(X_tr_scaled, verbose=0)
            scaled_test_pred  = current_model.predict(X_te_scaled, verbose=0)

            train_pred = current_scaler_y.inverse_transform(scaled_train_pred).flatten()
            test_pred  = current_scaler_y.inverse_transform(scaled_test_pred).flatten()

            # Calculate metrics using original unscaled true values
            mae_train = mean_absolute_error(y_tr_original, train_pred)
            mae_test  = mean_absolute_error(y_te_original, test_pred)
            r2_train  = r2_score(y_tr_original, train_pred)
            r2_test   = r2_score(y_te_original, test_pred)
            rmse_train = np.sqrt(np.mean((y_tr_original - train_pred)**2))
            rmse_test  = np.sqrt(np.mean((y_te_original - test_pred)**2))

            mlflow.log_metrics({
                "final_train_mae":  mae_train,
                "final_test_mae":   mae_test,
                "final_train_r2":   r2_train,
                "final_test_r2":    r2_test,
                "final_train_rmse": rmse_train,
                "final_test_rmse":  rmse_test,
                "epochs_trained":   len(history.history["loss"])
            })

            mlflow.keras.log_model(current_model, f"lstm_model_fold_{fold_idx}")

            fold_results.append({
                "mae_test": mae_test, "r2_test": r2_test, "rmse_test": rmse_test
            })
            print(f"Fold {fold_idx} → test_mae={mae_test:.4f}, test_r2={r2_test:.4f}")

    # ── Log CV summary metrics on parent run ──────────────────────
    mlflow.log_metrics({
        "cv_mean_test_mae":  np.mean([r["mae_test"]  for r in fold_results]),
        "cv_std_test_mae":   np.std( [r["mae_test"]  for r in fold_results]),
        "cv_mean_test_r2":   np.mean([r["r2_test"]   for r in fold_results]),
        "cv_mean_test_rmse": np.mean([r["rmse_test"] for r in fold_results]),
    })

    print("\nMLflow parent run completed with all folds.")
# Out:
# 2026/06/21 08:03:28 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2026/06/21 08:03:28 INFO mlflow.store.db.utils: Updating database tables
# 2026/06/21 08:03:30 INFO mlflow.tracking.fluent: Experiment with name 'Stock Price Prediction - LSTM Model' does not exist. Creating a new experiment.
# 2026/06/21 08:03:36 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/21 08:03:36 WARNING mlflow.keras.save: You are saving a Keras model without specifying model signature.
# Fold 4 → test_mae=6.4668, test_r2=0.8333
#
# MLflow parent run completed with all folds.

# %% [markdown]
# ### Using ngrok

# %%
import subprocess, time, requests, os, re
from pyngrok import ngrok
from google.colab import userdata

# ── 1. Kill everything ────────────────────────────────────────────
subprocess.run("pkill -f 'mlflow server'", shell=True)
subprocess.run("pkill -f proxy.py", shell=True)
subprocess.run("pkill -f cloudflared", shell=True)
time.sleep(3)

# ── 2. Start MLflow ───────────────────────────────────────────────
env = os.environ.copy()
env["GUNICORN_CMD_ARGS"] = "--forwarded-allow-ips='*'"

subprocess.Popen(
    ["mlflow", "server",
     "--backend-store-uri", "sqlite:////content/Predictive-Analytics-Public-Datasets/mlflow.db",
     "--serve-artifacts",
     "--host", "0.0.0.0",
     "--port", "5000",
     "--cors-allowed-origins", "https://ia-mlflow-dashboard.ngrok.app"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.STDOUT,
    cwd="/content/Predictive-Analytics-Public-Datasets",
    env=env
)

print("Waiting for MLflow...")
for i in range(30):
    try:
        r = requests.get("http://localhost:5000/health", timeout=3)
        if r.status_code == 200:
            print(f"MLflow ready")
            break
    except Exception:
        pass
    time.sleep(2)

# ── 3. Write proxy (rewrites Host header to localhost:5000) ────────
proxy_code = """
import http.server
import http.client
import urllib.parse

class Proxy(http.server.BaseHTTPRequestHandler):
    def _proxy(self, body=None):
        parsed = urllib.parse.urlparse(f"http://localhost:5000{self.path}")

        conn = http.client.HTTPConnection("localhost", 5000, timeout=30)

        headers = dict(self.headers)
        headers["Host"] = "localhost:5000"
        headers["X-Forwarded-Host"] = "localhost:5000"
        headers["X-Forwarded-Proto"] = "http"
        headers.pop("Transfer-Encoding", None)
        headers.pop("transfer-encoding", None)

        try:
            conn.request(self.command, parsed.path + (f"?{parsed.query}" if parsed.query else ""), body=body, headers=headers)
            resp = conn.getresponse()

            self.send_response(resp.status)

            for k, v in resp.getheaders():
                if k.lower() not in ("transfer-encoding", "connection", "keep-alive"):
                    self.send_header(k, v)
            self.send_header("Access-Control-Allow-Origin", "*")
            self.send_header("Access-Control-Allow-Headers", "*")
            self.end_headers()

            # Stream response in chunks — fixes chart data loading
            while True:
                chunk = resp.read(8192)
                if not chunk:
                    break
                self.wfile.write(chunk)
            self.wfile.flush()

        except Exception as e:
            self.send_response(502)
            self.end_headers()
            self.wfile.write(str(e).encode())
        finally:
            conn.close()

    def do_GET(self):     self._proxy()
    def do_POST(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_PUT(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_DELETE(self):  self._proxy()
    def do_OPTIONS(self):
        self.send_response(200)
        self.send_header("Access-Control-Allow-Origin", "*")
        self.send_header("Access-Control-Allow-Methods", "GET, POST, PUT, DELETE, OPTIONS")
        self.send_header("Access-Control-Allow-Headers", "*")
        self.end_headers()
    def log_message(self, *args): pass

server = http.server.HTTPServer(('0.0.0.0', 5001), Proxy)
server.serve_forever()
"""

with open("proxy.py", "w") as f:
    f.write(proxy_code)

subprocess.Popen(["python", "proxy.py"],
                 stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
print("Proxy started on port 5001")
time.sleep(3)

# ── 4. Connect ngrok to proxy on port 5001 ────────────────────────
ngrok.set_auth_token(userdata.get('NGROK_AUTH_TOKEN'))

# Replace with your custom domain
public_url = ngrok.connect(5001, domain="ia-mlflow-dashboard.ngrok.app")
print(f"\nMLflow UI: {public_url}\n")
# Out:
# Waiting for MLflow...
# MLflow ready
# Proxy started on port 5001
#
# MLflow UI: NgrokTunnel: "https://ia-mlflow-dashboard.ngrok.app" -> "http://localhost:5001"

# %%
import mlflow
import mlflow.langchain
import mlflow.openai
import os
import json
import mlflow.tensorflow # Import mlflow.tensorflow for Keras autologging

# Set the MLflow tracking URI to connect to the server started by ngrok
# The ngrok setup usually exposes localhost:5000
mlflow.set_tracking_uri("http://localhost:5000")

# Set an experiment name for better organization in the MLflow UI
mlflow.set_experiment("Apple Stock Prediction")

# Enable autologging for TensorFlow/Keras models
mlflow.tensorflow.autolog()

print("MLflow tracking setup complete.")
# Out:
# 2026/06/21 08:09:15 INFO mlflow.tracking.fluent: Experiment with name 'Apple Stock Prediction' does not exist. Creating a new experiment.
# MLflow tracking setup complete.

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %% [markdown]
# Verify if the tunnel is still alive and the UI can actually reach the run

# %%
import subprocess, time

subprocess.run("pkill -f mlflow", shell=True)
subprocess.run("pkill -f cloudflared", shell=True)
subprocess.run("pkill -f proxy.py", shell=True)
time.sleep(3)
print("Environment cleaned.")

# %% [markdown]
# ### The cell below works but sticking with ngrok due optimized routing making it very fast in comparison to cloudflare

# %%
'''import subprocess, time, re, requests

# ── 1. Kill everything ────────────────────────────────────────────
subprocess.run("pkill -f mlflow", shell=True)
subprocess.run("pkill -f cloudflared", shell=True)
subprocess.run("pkill -f proxy.py", shell=True)
time.sleep(4)

# ── 2. Download cloudflared ───────────────────────────────────────
print("Downloading cloudflared...")
subprocess.run("wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared", shell=True)
subprocess.run("chmod +x cloudflared", shell=True)
print("cloudflared installed.")

# ── 3. Start MLflow with CSRF disabled ───────────────────────────
import os
env = os.environ.copy()
env["MLFLOW_CSRF_PROTECTION"] = "false"          # disable CSRF in MLflow 3.x
env["GUNICORN_CMD_ARGS"] = "--forwarded-allow-ips=*"

subprocess.Popen(
    ["mlflow", "server",
     "--backend-store-uri", "sqlite:////content/Predictive-Analytics-Public-Datasets/mlflow.db",
     "--artifacts-destination", "/content/Predictive-Analytics-Public-Datasets/mlruns",
     "--serve-artifacts",
     "--host", "0.0.0.0",
     "--port", "5000"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.STDOUT,
    cwd="/content/Predictive-Analytics-Public-Datasets",
    env=env
)

print("Waiting for MLflow...")
for i in range(30):
    try:
        r = requests.get("http://localhost:5000/health", timeout=3)
        if r.status_code == 200:
            print(f" MLflow ready after {(i+1)*2}s")
            break
    except Exception:
        pass
    time.sleep(2)

# ── 4. Write proxy (rewrites Origin + Referer to match Host) ──────
proxy_code = """
import http.server
import http.client
import urllib.parse

MLFLOW_HOST = "localhost:5000"

class Proxy(http.server.BaseHTTPRequestHandler):
    def _proxy(self, body=None):
        parsed = urllib.parse.urlparse(f"http://{MLFLOW_HOST}{self.path}")
        query  = f"?{parsed.query}" if parsed.query else ""
        path   = parsed.path + query

        headers = dict(self.headers)

        # ── Rewrite ALL headers that MLflow CSRF checks ───────────
        headers["Host"]              = MLFLOW_HOST
        headers["X-Forwarded-Host"]  = MLFLOW_HOST
        headers["X-Forwarded-Proto"] = "http"

        # Rewrite Origin so it matches Host — fixes CSRF POST block
        if "Origin" in headers:
            headers["Origin"] = f"http://{MLFLOW_HOST}"

        # Rewrite Referer so it matches Host
        if "Referer" in headers:
            referer = headers["Referer"]
            parsed_ref = urllib.parse.urlparse(referer)
            headers["Referer"] = parsed_ref._replace(
                scheme="http", netloc=MLFLOW_HOST
            ).geturl()

        # Strip headers that break http.client connection
        for h in ("Transfer-Encoding", "transfer-encoding",
                  "Connection", "connection"):
            headers.pop(h, None)

        try:
            conn = http.client.HTTPConnection("localhost", 5000, timeout=60)
            conn.request(self.command, path, body=body, headers=headers)
            resp = conn.getresponse()

            self.send_response(resp.status)
            for k, v in resp.getheaders():
                if k.lower() not in ("transfer-encoding", "connection", "keep-alive"):
                    self.send_header(k, v)
            self.send_header("Access-Control-Allow-Origin", "*")
            self.send_header("Access-Control-Allow-Headers", "*")
            self.end_headers()

            # Stream in chunks — preserves chart data responses
            while True:
                chunk = resp.read(8192)
                if not chunk:
                    break
                self.wfile.write(chunk)
            self.wfile.flush()
            conn.close()

        except Exception as e:
            self.send_response(502)
            self.end_headers()
            self.wfile.write(str(e).encode())

    def do_GET(self):    self._proxy()
    def do_POST(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_PUT(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_DELETE(self): self._proxy()
    def do_OPTIONS(self):
        self.send_response(200)
        self.send_header("Access-Control-Allow-Origin", "*")
        self.send_header("Access-Control-Allow-Methods", "GET, POST, PUT, DELETE, OPTIONS")
        self.send_header("Access-Control-Allow-Headers", "*")
        self.end_headers()
    def log_message(self, *args): pass

server = http.server.HTTPServer(('0.0.0.0', 5001), Proxy)
print("[PROXY] Started on port 5001")
server.serve_forever()
"""

with open("proxy.py", "w") as f:
    f.write(proxy_code)

subprocess.Popen(["python", "proxy.py"],
                 stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
print(" Proxy started on port 5001")
time.sleep(4)

# ── 5. Start Cloudflare tunnel ────────────────────────────────────
proc = subprocess.Popen(
    ["./cloudflared", "tunnel", "--url", "http://localhost:5001"],
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT
)

public_url = None
print("Waiting for Cloudflare tunnel...")
for line in proc.stdout:
    line = line.decode()
    if "trycloudflare.com" in line:
        match = re.search(r'https://[a-zA-Z0-9\-]+\.trycloudflare\.com', line)
        if match:
            public_url = match.group()
            break

if not public_url:
    print("Could not extract tunnel URL.")
else:
    print("Tunnel established. Waiting for DNS propagation...")
    time.sleep(20)

    for attempt in range(10):
        try:
            r = requests.get(public_url, timeout=10)
            print(f"\n MLflow UI is live: {public_url}\n")
            break
        except Exception as e:
            print(f"Not reachable yet (attempt {attempt+1}/10): {e}")
            time.sleep(10)
    else:
        print(f"\n  Try opening manually: {public_url}")'''

# %% [markdown]
# Check if runs is logged into experiments

# %%
import requests

runs = requests.post(
    "http://localhost:5001/api/2.0/mlflow/runs/search",
    json={"experiment_ids": ["1"], "max_results": 50}
).json()

print(f"Number of runs: {len(runs.get('runs', []))}")
for run in runs.get('runs', []):
    info = run['info']
    metrics = run.get('data', {}).get('metrics', [])
    print(f"\nRun ID: {info['run_id']}")
    print(f"Status: {info['status']}")
    print(f"Metrics: {metrics}")

# %% [markdown]
# tells us if the LSTM_Fold4_epoch_history run with epoch-level metrics is actually in the db.

# %%
import requests

runs = requests.post(
    "http://localhost:5001/api/2.0/mlflow/runs/search",
    json={"experiment_ids": ["1"], "max_results": 50}
).json()

for run in runs.get("runs", []):
    info = run["info"]
    metrics = run.get("data", {}).get("metrics", [])
    params  = run.get("data", {}).get("params", [])
    print(f"Run: {info['run_name']} | ID: {info['run_id']} | Metrics: {len(metrics)} | Params: {len(params)}")

# %% [markdown]
# Check if ML server is still responding

# %%
import requests

# Check if MLflow server is still responding
try:
    r = requests.get("http://localhost:5001/health", timeout=5)
    print("Health:", r.status_code, r.text)
except Exception as e:
    print("Server down:", e)

# Check if runs are still in DB
try:
    r = requests.post(
        "http://localhost:5001/api/2.0/mlflow/runs/search",
        json={"experiment_ids": ["1"], "max_results": 50}
    ).json()
    print("Runs found:", len(r.get("runs", [])))
except Exception as e:
    print("Runs search failed:", e)

# %%
# Check if the server is actually responding
# !curl -X POST http://localhost:5001/api/2.0/mlflow/experiments/search \
  -H "Content-Type: application/json" \
  -d '{"max_results": 100}'

# %% [markdown]
# Check specific run

# %%
import requests

runs = requests.post(
    "http://localhost:5000/api/2.0/mlflow/runs/search",
    json={"experiment_ids": ["1"], "max_results": 50}
).json()

for run in runs.get("runs", []):
    info = run["info"]
    metrics = run.get("data", {}).get("metrics", [])
    print(f"{info['run_name']} | {info['run_id']} | {len(metrics)} metrics")

# %%
import requests

# Check experiment directly
exp = requests.get(
    "http://localhost:5000/api/2.0/mlflow/experiments/get?experiment_id=1"
).json()
print("Experiment artifact location:", exp["experiment"]["artifact_location"])

# Check run artifact URIs
runs = requests.post(
    "http://localhost:5000/api/2.0/mlflow/runs/search",
    json={"experiment_ids": ["1"], "max_results": 50}
).json()

for run in runs.get("runs", []):
    print(f"{run['info']['run_name']} | artifact_uri: {run['info']['artifact_uri']}")

# %%
import subprocess, time

subprocess.run("pkill -f 'mlflow server'", shell=True)
time.sleep(3)

# Find where mlruns actually lives
result = subprocess.run("find /content -name 'mlruns' -type d 2>/dev/null",
                        shell=True, capture_output=True, text=True)
print("mlruns found at:", result.stdout.strip())

# %% [markdown]
# Check if the tunnel is still live
# ### Notice when i run this, cloudfare tunnel goes down

# %%
'''import requests

# Replace with your current trycloudflare.com URL
PUBLIC_URL = "https://edmonton-ham-rpm-berkeley.trycloudflare.com"

try:
    r = requests.get(f"{PUBLIC_URL}/api/2.0/mlflow/experiments/search",
                     json={"max_results": 10}, timeout=20)
    print("Tunnel status:", r.status_code)
except Exception as e:
    print("Tunnel is down:", e)'''

# %% [markdown]
# Tunnel status 530 means thee tunnel process has died. MLflow is unreachable or th URL has expired

# %% [markdown]
# Cloudfare is blocking the request not MLflow. Cloudflare's free tunnel flags certain API requests as suspicious.

# %% [markdown]
# ### mlflow for keras

# %%
# !ps aux | grep mlflow

# %%
print('Checking active processes on port 5001:')
# !lsof -i :5001
# If lsof is not installed, you can try:
#!netstat -tuln | grep 5000
#!fuser 5000/tcp

# %%
#!ngrok version

# %% [markdown]
# Using cloudfare for MLflow, https and avoid the http of ngronk using .app

# %% [markdown]
# Checking for MLflow experiment

# %%
experiments = mlflow.search_experiments()
print(experiments)
#for exp in experiments:
    #print(f"Name: {exp.name}, Experiment_id: {exp.experiment_id}")

# %% [markdown]
# checking artifact location

# %%
import requests

runs = requests.post(
    "http://localhost:5001/api/2.0/mlflow/runs/search",
    json={"experiment_ids": ["1"], "max_results": 50}
).json()

for run in runs.get("runs", []):
    info = run["info"]
    print(f"{info['run_name']} | artifact_uri: {info['artifact_uri']}")

# %%
import requests
r = requests.get("http://localhost:5001/api/2.0/mlflow/experiments/search?max_results=100")
print(r.json())

# %% [markdown]
# Google proxy for localhost

# %%
from google.colab import output
# Replace 5000 with your MLflow port if different
print(output.eval_js("google.colab.kernel.proxyPort(5001)"))

# %% [markdown]
# ## Using ngrok

# %%
import subprocess, time, requests, os, re
from pyngrok import ngrok
from google.colab import userdata

# ── 1. Kill everything ────────────────────────────────────────────
subprocess.run("pkill -f 'mlflow server'", shell=True)
subprocess.run("pkill -f proxy.py", shell=True)
subprocess.run("pkill -f cloudflared", shell=True)
time.sleep(3)

# ── 2. Start MLflow ───────────────────────────────────────────────
env = os.environ.copy()
env["GUNICORN_CMD_ARGS"] = "--forwarded-allow-ips='*'"

subprocess.Popen(
    ["mlflow", "server",
     "--backend-store-uri", "sqlite:////content/Predictive-Analytics-Public-Datasets/mlflow.db",
     "--serve-artifacts",
     "--host", "0.0.0.0",
     "--port", "5000",
     "--cors-allowed-origins", "https://ia-mlflow-dashboard.ngrok.app"],
    stdout=subprocess.DEVNULL,
    stderr=subprocess.STDOUT,
    cwd="/content/Predictive-Analytics-Public-Datasets",
    env=env
)

print("Waiting for MLflow...")
for i in range(30):
    try:
        r = requests.get("http://localhost:5000/health", timeout=3)
        if r.status_code == 200:
            print(f"MLflow ready")
            break
    except Exception:
        pass
    time.sleep(2)

# ── 3. Write proxy (rewrites Host header to localhost:5000) ────────
proxy_code = """
import http.server
import http.client
import urllib.parse

class Proxy(http.server.BaseHTTPRequestHandler):
    def _proxy(self, body=None):
        parsed = urllib.parse.urlparse(f"http://localhost:5000{self.path}")

        conn = http.client.HTTPConnection("localhost", 5000, timeout=30)

        headers = dict(self.headers)
        headers["Host"] = "localhost:5000"
        headers["X-Forwarded-Host"] = "localhost:5000"
        headers["X-Forwarded-Proto"] = "http"
        headers.pop("Transfer-Encoding", None)
        headers.pop("transfer-encoding", None)

        try:
            conn.request(self.command, parsed.path + (f"?{parsed.query}" if parsed.query else ""), body=body, headers=headers)
            resp = conn.getresponse()

            self.send_response(resp.status)

            for k, v in resp.getheaders():
                if k.lower() not in ("transfer-encoding", "connection", "keep-alive"):
                    self.send_header(k, v)
            self.send_header("Access-Control-Allow-Origin", "*")
            self.send_header("Access-Control-Allow-Headers", "*")
            self.end_headers()

            # Stream response in chunks — fixes chart data loading
            while True:
                chunk = resp.read(8192)
                if not chunk:
                    break
                self.wfile.write(chunk)
            self.wfile.flush()

        except Exception as e:
            self.send_response(502)
            self.end_headers()
            self.wfile.write(str(e).encode())
        finally:
            conn.close()

    def do_GET(self):     self._proxy()
    def do_POST(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_PUT(self):
        length = int(self.headers.get("Content-Length", 0))
        self._proxy(self.rfile.read(length) if length else None)
    def do_DELETE(self):  self._proxy()
    def do_OPTIONS(self):
        self.send_response(200)
        self.send_header("Access-Control-Allow-Origin", "*")
        self.send_header("Access-Control-Allow-Methods", "GET, POST, PUT, DELETE, OPTIONS")
        self.send_header("Access-Control-Allow-Headers", "*")
        self.end_headers()
    def log_message(self, *args): pass

server = http.server.HTTPServer(('0.0.0.0', 5001), Proxy)
server.serve_forever()
"""

with open("proxy.py", "w") as f:
    f.write(proxy_code)

subprocess.Popen(["python", "proxy.py"],
                 stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
print("Proxy started on port 5001")
time.sleep(3)

# ── 4. Connect ngrok to proxy on port 5001 ────────────────────────
ngrok.set_auth_token(userdata.get('NGROK_AUTH_TOKEN'))

# Replace with your custom domain
public_url = ngrok.connect(5001, domain="ia-mlflow-dashboard.ngrok.app")
print(f"\nMLflow UI: {public_url}\n")

# %% [markdown]
# MLflow 3.14.0 has built-in CSRF protection that blocks POST requests when the Origin header (https://ia-mlflow-dashboard.ngrok.app) doesn't match the Host header (localhost:5000) rewritten by the proxy.
#
# Fix applied: Added "--cors-allowed-origins", "https://ia-mlflow-dashboard.ngrok.app" to the mlflow server Popen call in cell [86]. This is the correct flag name for mlflow server (distinct from --allow-origins used by mlflow ui).
